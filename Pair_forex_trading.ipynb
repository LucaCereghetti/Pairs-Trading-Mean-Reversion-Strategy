# %% [markdown]
# # Pairs Trading Mean Reversion Strategy

# %% [markdown]
# ## Account Connection with Interactive Brokers

# %%
import pandas as pd
from ib_insync import Forex, IB, util
from statsmodels.tsa.stattools import adfuller, coint
import numpy as np
from scipy.optimize import minimize
from scipy.integrate import quad
import datetime as dt
import time
import nest_asyncio

nest_asyncio.apply()

# Connect to IBKR TWS or Gateway
ib = IB()
ib.connect('127.0.0.1', 7497, clientId=1)

myAccount = 'DU9177866'  ## Needs to be changed with the ouwn account number

# Check account balance
account_summary = ib.accountSummary(account=myAccount)
cash_balance = [item for item in account_summary if item.tag == 'TotalCashValue'][0].value
print(f"Account Cash Balance: {cash_balance}")
# Out:
# /Users/matteorampazzo/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Account Cash Balance: 1001785.99

# %% [markdown]
# ## Account Connection with Interactive Brokers

# %%
# Define pairs of currency assets
pairs = [
    ('EURUSD', 'GBPUSD'),  # EUR/USD and GBP/USD
    ('USDJPY', 'USDCAD'),  # USD/JPY and USD/CAD
    ('AUDUSD', 'USDCHF'),  # AUD/USD and USD/CHF
    ('NZDUSD', 'EURGBP'),  # NZD/USD and EUR/GBP
    ('EURGBP', 'USDJPY'),  # EUR/GBP and USD/JPY
    ('USDCHF', 'USDJPY'),  # USD/CHF and USD/JPY
    ('EURJPY', 'GBPJPY'),  # EUR/JPY and GBP/JPY
    ('AUDJPY', 'NZDJPY'),  # AUD/JPY and NZD/JPY
    ('EURCHF', 'GBPCHF'),  # EUR/CHF and GBP/CHF
    ('AUDNZD', 'EURNZD'),  # AUD/NZD and EUR/NZD
    ('USDSGD', 'USDHKD'),  # USD/SGD and USD/HKD
    ('CADJPY', 'CHFJPY'),  # CAD/JPY and CHF/JPY
    ('GBPAUD', 'GBPCAD'),  # GBP/AUD and GBP/CAD
    ('EURAUD', 'EURCAD'),  # EUR/AUD and EUR/CAD
    ('USDNOK', 'USDSEK'),  # USD/NOK and USD/SEK
    ('EURTRY', 'USDTRY'),  # EUR/TRY and USD/TRY
    ('EURGBP', 'AUDJPY'),  # EUR/GBP and AUD/JPY
    ('EURGBP', 'GBPJPY'),  # EUR/GBP and GBP/JPY
    ('EURGBP', 'CHFJPY'),  # EUR/GBP and CHF/JPY
    ('EURGBP', 'USDSGD'),  # EUR/GBP and USD/SGD
    ('EURGBP', 'CADJPY'),  # EUR/GBP and CAD/JPY
    ('EURGBP', 'EURJPY'),  # EUR/GBP and EUR/JPY
    ('EURGBP', 'GBPCAD'),  # EUR/GBP and GBPCAD
    ('EURGBP', 'NZDJPY'),  # EUR/GBP and NZD/JPY
    ('AUDJPY', 'GBPJPY'),  # AUD/JPY and GBP/JPY
    ('AUDJPY', 'CHFJPY'),  # AUD/JPY and CHF/JPY
    ('AUDJPY', 'USDSGD'),  # AUD/JPY and USD/SGD
    ('AUDJPY', 'CADJPY'),  # AUD/JPY and CAD/JPY
    ('AUDJPY', 'EURJPY'),  # AUD/JPY and EUR/JPY
    ('AUDJPY', 'GBPCAD'),  # AUD/JPY and GBPCAD
    ('AUDJPY', 'USDJPY'),  # AUD/JPY and USD/JPY
    ('GBPJPY', 'CHFJPY'),  # GBP/JPY and CHF/JPY
    ('GBPJPY', 'USDSGD'),  # GBP/JPY and USD/SGD
    ('GBPJPY', 'CADJPY'),  # GBP/JPY and CAD/JPY
    ('GBPJPY', 'EURJPY'),  # GBP/JPY and EUR/JPY
    ('GBPJPY', 'GBPCAD'),  # GBP/JPY and GBPCAD
    ('GBPJPY', 'USDJPY'),  # GBP/JPY and USD/JPY
    ('CHFJPY', 'USDSGD'),  # CHF/JPY and USD/SGD
    ('CHFJPY', 'CADJPY'),  # CHF/JPY and CAD/JPY
    ('CHFJPY', 'EURJPY'),  # CHF/JPY and EUR/JPY
    ('CHFJPY', 'GBPCAD'),  # CHF/JPY and GBPCAD
    ('CHFJPY', 'NZDJPY'),  # CHF/JPY and NZD/JPY
    ('USDSGD', 'CADJPY'),  # USD/SGD and CAD/JPY
    ('USDSGD', 'EURJPY'),  # USD/SGD and EUR/JPY
    ('USDSGD', 'GBPCAD'),  # USD/SGD and GBPCAD
    ('CADJPY', 'EURJPY'),  # CAD/JPY and EUR/JPY
    ('CADJPY', 'GBPCAD'),  # CAD/JPY and GBPCAD
    ('CADJPY', 'NZDJPY'),  # CAD/JPY and NZD/JPY
    ('EURJPY', 'GBPCAD'),  # EUR/JPY and GBPCAD
    ('EURJPY', 'USDJPY'),  # EUR/JPY and USD/JPY
    ('GBPCAD', 'USDJPY'),  # GBP/CAD and USD/JPY
    ('GBPJPY', 'NZDJPY'),  # GBP/JPY and NZD/JPY
    ('USDJPY', 'NZDJPY')   # USD/JPY and NZD/JPY
]

# Define the start and end dates for downloading data
start_date = '20240101 00:00:00'
end_date = '20240531 23:59:59'

# Function to fetch historical data from IBKR
def fetch_historical_data(contract, start_date, end_date, bar_size='1 hour'):
    df_list = []
    current_end_date = dt.datetime.strptime(end_date, '%Y%m%d %H:%M:%S')

    while True:
        try:
            bars = ib.reqHistoricalData(
                contract,
                endDateTime=current_end_date.strftime('%Y%m%d %H:%M:%S'),
                durationStr='1 M',  # Fetch 1 month of data at a time
                barSizeSetting=bar_size,
                whatToShow='MIDPOINT',
                useRTH=False,
                formatDate=1
            )
            if not bars:
                break
            df = util.df(bars)
            df_list.append(df)
            # Subtract one second and ensure naive datetime
            current_end_date = df['date'].iloc[0].to_pydatetime().replace(tzinfo=None) - dt.timedelta(seconds=1)
            time.sleep(1)  # Respect IBKR API rate limits
            if current_end_date <= dt.datetime.strptime(start_date, '%Y%m%d %H:%M:%S'):
                break
        except Exception as e:
            print(f"Error fetching data for {contract.symbol}: {e}")
            break

    if df_list:
        return pd.concat(df_list).sort_index()
    else:
        return None

# Extract unique tickers from pairs
unique_tickers = set(ticker for pair in pairs for ticker in pair)

print("Initialization complete and ready for ADF test.")
# Out:
# Initialization complete and ready for ADF test.

# %% [markdown]
# ## ADF Test

# %%
# Function to perform the ADF test and print the results
def adf_test(series, name):
    series = series.dropna()
    result = adfuller(series)
    test_statistic = f'{result[0]:.3f}'
    p_value = f'{result[1]:.6f}'  # Display p-value with higher precision
    critical_values_str = ', '.join([f'{key}: {value:.3f}' for key, value in result[4].items()])

    # Determine if the series is stationary
    status = 'stationary' if result[1] < 0.05 else 'non-stationary'

    # Print the result
    print(f'{name} Test Statistic: {test_statistic}, p-value: {p_value}. Critical Values: {critical_values_str}. The series is likely {status}.')

# Fetch and perform the ADF test for each ticker
for ticker in unique_tickers:
    print(f"Fetching data for {ticker}...")
    contract = Forex(ticker)
    data = fetch_historical_data(contract, start_date, end_date, bar_size='1 hour')
    if data is not None:
        print(f"Performing ADF test for {ticker}...")
        adf_test(data['close'], ticker)
    else:
        print(f"No data fetched for {ticker}")

print("ADF test complete.")
# Out:
# Fetching data for AUDUSD...
# Performing ADF test for AUDUSD...
# AUDUSD Test Statistic: -3.851, p-value: 0.002425. Critical Values: 1%: -3.432, 5%: -2.862, 10%: -2.567. The series is likely stationary.
# Fetching data for EURGBP...
# Performing ADF test for EURGBP...
# EURGBP Test Statistic: -2.639, p-value: 0.085131. Critical Values: 1%: -3.432, 5%: -2.862, 10%: -2.567. The series is likely non-stationary.
# Fetching data for USDCAD...
# Performing ADF test for USDCAD...
# USDCAD Test Statistic: -3.108, p-value: 0.025954. Critical Values: 1%: -3.432, 5%: -2.862, 10%: -2.567. The series is likely stationary.
# Fetching data for USDCHF...
# Performing ADF test for USDCHF...
# USDCHF Test Statistic: -3.503, p-value: 0.007920. Critical Values: 1%: -3.432, 5%: -2.862, 10%: -2.567. The series is likely stationary.
# Fetching data for USDJPY...
# Performing ADF test for USDJPY...
# USDJPY Test Statistic: -1.570, p-value: 0.498531. Critical Values: 1%: -3.432, 5%: -2.862, 10%: -2.567. The series is likely non-stationary.
# Fetching data for EURUSD...
# Performing ADF test for EURUSD...
# EURUSD Test Statistic: -3.934, p-value: 0.001800. Critical Values: 1%: -3.432, 5%: -2.862, 10%: -2.567. The series is likely stationary.
# Fetching data for NZDUSD...
# Performing ADF test for NZDUSD...
# NZDUSD Test Statistic: -5.095, p-value: 0.000014. Critical Values: 1%: -3.432, 5%: -2.862, 10%: -2.567. The series is likely stationary.
# Fetching data for GBPUSD...
# Performing ADF test for GBPUSD...
# GBPUSD Test Statistic: -3.719, p-value: 0.003858. Critical Values: 1%: -3.432, 5%: -2.862, 10%: -2.567. The series is likely stationary.
# ADF test complete.

# %% [markdown]
# ## CADF test

# %%
########################################## CHAT GPT-4 ##########################################
## Create using Chat GPT-4, explaining the concept and ask for suggestion on how to make the code

# Function to perform the CADF test and print the results
def cadf_test(series1, series2, name1, name2):
    series1 = series1.dropna()
    series2 = series2.dropna()

    # Ensure both series have the same length
    if len(series1) != len(series2):
        min_len = min(len(series1), len(series2))
        series1 = series1[-min_len:]
        series2 = series2[-min_len:]

    score, p_value, critical_values = coint(series1, series2)
    test_statistic = f'{score:.3f}'
    p_value_formatted = f'{p_value:.6f}'

    critical_values_str = ', '.join([f'{key}: {value:.3f}' for key, value in zip(['1%', '5%', '10%'], critical_values)])

    # Determine if the series are cointegrated
    status = 'cointegrated' if p_value < 0.05 else 'not cointegrated'

    # Print the result
    print(f'{name1} & {name2} Test Statistic: {test_statistic}, p-value: {p_value_formatted}. The series are likely {status}.')


# Perform the CADF test for each pair
for name1, name2 in pairs:
    print(f"Fetching data for {name1} and {name2}...")
    contract1 = Forex(name1)
    contract2 = Forex(name2)
    
    data1 = fetch_historical_data(contract1, start_date, end_date, bar_size='1 hour')
    data2 = fetch_historical_data(contract2, start_date, end_date, bar_size='1 hour')
    
    if data1 is not None and data2 is not None:
        print(f"Performing CADF test for {name1} and {name2}...")
        cadf_test(data1['close'], data2['close'], name1, name2)
    else:
        if data1 is None:
            print(f"No data fetched for {name1}")
        if data2 is None:
            print(f"No data fetched for {name2}")

print("CADF test complete.")
# Out:
# Fetching data for EURUSD and GBPUSD...
# Performing CADF test for EURUSD and GBPUSD...
# EURUSD & GBPUSD Test Statistic: -2.688, p-value: 0.203837. The series are likely not cointegrated.
# Fetching data for USDJPY and USDCAD...
# Performing CADF test for USDJPY and USDCAD...
# USDJPY & USDCAD Test Statistic: -0.889, p-value: 0.921890. The series are likely not cointegrated.
# Fetching data for AUDUSD and USDCHF...
# Performing CADF test for AUDUSD and USDCHF...
# AUDUSD & USDCHF Test Statistic: -3.590, p-value: 0.025182. The series are likely cointegrated.
# Fetching data for NZDUSD and EURGBP...
# Performing CADF test for NZDUSD and EURGBP...
# NZDUSD & EURGBP Test Statistic: -5.162, p-value: 0.000082. The series are likely cointegrated.
# CADF test complete.

# %%
# Disconnect from IBKR
ib.disconnect()

# %% [markdown]
# # **** BACKTESTING ****
# In this section, we will backtest our strategy using optimal timing strategies for trading a mean-reverting price spread. We'll optimize the positions of AUDJPY and CADJPY to ensure the intraday portfolio value aligns closely with an Ornstein-Uhlenbeck (OU) process, using maximum likelihood estimation for the best fit.

# %% [markdown]
# ### 1 - Account connection and Data acquisition¶

# %%
import nest_asyncio
from scipy.optimize import minimize
from ib_insync import *
import pandas as pd
import datetime as dt
import time
import numpy as np
from scipy.integrate import quad

# Apply nest_asyncio to avoid asyncio loop issues
nest_asyncio.apply()

# Connect to IBKR TWS or Gateway
ib = IB()
ib.connect('127.0.0.1', 7497, clientId=1)

myAccount = 'DU9177866'

valuta1_contract = Forex('AUDJPY')
valuta2_contract = Forex('CADJPY')

# Function to fetch historical data for a month
def fetch_month_data(contract, start_date='20240501 00:00:00', end_date='20240531 23:59:59', bar_size='15 mins'):
    df_list = []
    current_end_date = dt.datetime.strptime(end_date, '%Y%m%d %H:%M:%S')

    while True:
        try:
            bars = ib.reqHistoricalData(
                contract,
                endDateTime=current_end_date.strftime('%Y%m%d %H:%M:%S'),
                durationStr='1 M',
                barSizeSetting=bar_size,
                whatToShow='MIDPOINT',
                useRTH=False,
                formatDate=1
            )
            if not bars:
                break
            df = util.df(bars)
            df_list.append(df)
            current_end_date = df['date'].iloc[0].to_pydatetime().replace(tzinfo=None) - dt.timedelta(seconds=1)
            time.sleep(1)
            if current_end_date <= dt.datetime.strptime(start_date, '%Y%m%d %H:%M:%S'):
                break
        except Exception as e:
            print(f"Error fetching data: {e}")
            break

    return pd.concat(df_list).sort_index() if df_list else None

# Fetch data for AUD/JPY and CAD/JPY
valuta1_data = fetch_month_data(valuta1_contract, start_date='20240501 00:00:00', end_date='20240531 23:59:59', bar_size='15 mins')
valuta2_data = fetch_month_data(valuta2_contract, start_date='20240501 00:00:00', end_date='20240531 23:59:59', bar_size='15 mins')

# Disconnect from IBKR
ib.disconnect()

# Ensure data is properly fetched
if valuta1_data is None or valuta2_data is None:
    raise ValueError("Failed to fetch data for one or both contracts.")

# Print column names to debug
print("Columns in valuta1_data:", valuta1_data.columns)
print("Columns in valuta2_data:", valuta2_data.columns)

# Convert the 'date' column to datetime and set as index
valuta1_data['date'] = pd.to_datetime(valuta1_data['date'])
valuta2_data['date'] = pd.to_datetime(valuta2_data['date'])
valuta1_data.set_index('date', inplace=True)
valuta2_data.set_index('date', inplace=True)

# Resample to 15-minute intervals
valuta1_resampled = valuta1_data.resample('15min').last().dropna()
valuta2_resampled = valuta2_data.resample('15min').last().dropna()

# Merge datasets
merged_data = pd.merge(valuta1_resampled, valuta2_resampled, left_index=True, right_index=True, suffixes=('_valuta1', '_valuta2'))
merged_data.dropna(inplace=True)

# Extract price arrays
valuta1_prices = merged_data['close_valuta1'].values
valuta2_prices = merged_data['close_valuta2'].values

print("Data fetching and preparation complete.")
# Out:
# /Users/matteorampazzo/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Columns in valuta1_data: Index(['date', 'open', 'high', 'low', 'close', 'volume', 'average',
#        'barCount'],
#       dtype='object')
# Columns in valuta2_data: Index(['date', 'open', 'high', 'low', 'close', 'volume', 'average',
#        'barCount'],
#       dtype='object')
# Data fetching and preparation complete.

# %% [markdown]
# ### 2 - Optimization functions

# %%
# Function to construct portfolio
def construct_portfolio(valuta1_prices, valuta2_prices, B):
    return valuta1_prices - B * valuta2_prices

# Function to optimize pair ratio
def optimize_pair_ratio(valuta1_prices, valuta2_prices):
    def negative_log_likelihood(B):
        portfolio_values = construct_portfolio(valuta1_prices, valuta2_prices, B)
        portfolio_values = (portfolio_values - np.mean(portfolio_values)) / np.std(portfolio_values)
        _, theta, _ = optimize_ou_parameters(portfolio_values)
        return -theta
    result = minimize(negative_log_likelihood, 0.0, bounds=[(-2, 2)])
    B_opt = result.x[0]
    return B_opt

# Function to optimize OU parameters
def optimize_ou_parameters(portfolio_values):
    def ou_log_likelihood(params, X):
        mu, theta, sigma = params
        n = len(X)
        dt = 1
        X_diff = np.diff(X)
        X_prev = X[:-1]
        likelihood = (
            -n / 2 * np.log(2 * np.pi * sigma**2 * (1 - np.exp(-2 * mu * dt)) / (2 * mu))
            - (X_diff - (theta - X_prev) * (1 - np.exp(-mu * dt)))**2
            / (2 * sigma**2 * (1 - np.exp(-2 * mu * dt)) / (2 * mu))
        )
        return -np.sum(likelihood)
    
    initial_params = [0.1, portfolio_values.mean(), portfolio_values.std()]
    bounds = [(1e-6, 1), (None, None), (1e-6, 1)]
    result = minimize(ou_log_likelihood, initial_params, args=(portfolio_values,), bounds=bounds)
    print(f"Optimized OU parameters: {result.x}")
    return result.x

print("Optimization functions ready.")
# Out:
# Optimization functions ready.

# %% [markdown]
# ### 3 - Optimal exit level

# %%
def calculate_optimal_exit_level(theta, mu, sigma, c=0):
    if sigma < 1e-6 or mu < 1e-6:
        raise ValueError("Sigma or mu is too small, causing numerical instability in calculations.")
    
    def F(x):
        integral_result, _ = quad(
            lambda u: (u**(2*mu/sigma**2 - 1)) * np.exp(np.sqrt(2*mu/sigma**2) * (theta - x) * u - u**2 / 2), 
            0, 
            np.inf
        )
        return integral_result
    
    def F_prime(x):
        integral_result, _ = quad(
            lambda u: (u**(2*mu/sigma**2 - 2)) * np.exp(np.sqrt(2*mu/sigma**2) * (theta - x) * u - u**2 / 2) 
            * (np.sqrt(2*mu/sigma**2) * (theta - x) - u), 
            0, 
            np.inf
        )
        return integral_result
    
    def objective(b):
        return np.abs(F(b) - (b - c) * F_prime(b))
    
    result = minimize(objective, theta, bounds=[(theta - 5 * sigma, theta + 5 * sigma)])
    return result.x[0]

print("Optimal exit level calculation function ready.")
# Out:
# Optimal exit level calculation function ready.

# %% [markdown]
# ### 4 - Optimal exit signals

# %%
########################################## CHAT GPT-4 ##########################################
## Create using Chat GPT-4, explaining the concept and ask for suggestion on how to make the code


def calculate_optimal_exit_signals(portfolio_values, optimal_exit_level, window_size=30):
    signals = []
    for i in range(window_size, len(portfolio_values)):
        current_value = portfolio_values[i]
        moving_avg = np.mean(portfolio_values[i - window_size:i])
        std_dev = np.std(portfolio_values[i - window_size:i])
        if current_value < moving_avg - std_dev:
            signals.append(1)
        elif current_value > optimal_exit_level:
            signals.append(-1)
        else:
            signals.append(0)
    signals = [0] * window_size + signals
    return np.array(signals)

def simulate_optimal_exit_strategy(portfolio_values, signals, initial_cash=100000, trade_amount=50000):
    position = 0
    cash = initial_cash
    portfolio = []
    trade_log = []  # To log the trades
    min_length = min(len(signals), len(portfolio_values))
    for i in range(min_length):
        signal = signals[i]
        current_value = portfolio_values[i]
        if signal == 1 and position == 0:
            position = trade_amount / current_value
            cash -= trade_amount
            trade_log.append((i, 'BUY', current_value))
        elif signal == -1 and position > 0:
            cash += position * current_value
            position = 0
            trade_log.append((i, 'SELL', current_value))
        portfolio_value = cash + (position * current_value)
        portfolio.append(portfolio_value)
    return np.array(portfolio), trade_log

print("Signal generation and strategy simulation functions ready.")
# Out:
# Signal generation and strategy simulation functions ready.

# %% [markdown]
# ### 5 - Optimized parameters and trade

# %%
########################################## CHAT GPT-4 ##########################################
## Create using Chat GPT-4, explaining the concept and ask for suggestion on how to make the code


# Optimize pair ratio
B_opt = optimize_pair_ratio(valuta1_prices, valuta2_prices)
print(f"Optimized pair ratio B: {B_opt:.4f}")

# Construct the portfolio
portfolio_values = construct_portfolio(valuta1_prices, valuta2_prices, B_opt)

# Optimize the OU parameters
mu_opt, theta_opt, sigma_opt = optimize_ou_parameters(portfolio_values)
print(f"Optimized parameters: mu={mu_opt:.4f}, theta={theta_opt:.4f}, sigma={sigma_opt:.4f}")

# Calculate the optimal exit level
try:
    optimal_exit_level = calculate_optimal_exit_level(theta_opt, mu_opt, sigma_opt)
    print(f"Optimal exit level b: {optimal_exit_level:.4f}")
except ValueError as e:
    print(f"Error in calculating optimal exit level: {e}")
    optimal_exit_level = theta_opt  # Use theta as a fallback

# Calculate the optimal exit signals
optimal_exit_signals = calculate_optimal_exit_signals(portfolio_values, optimal_exit_level)

# Simulate the optimal exit strategy
portfolio_simulation, trade_log = simulate_optimal_exit_strategy(portfolio_values, optimal_exit_signals, initial_cash=100000, trade_amount=50000)

# Print the final portfolio value
final_value = portfolio_simulation[-1]
print(f"Final portfolio value: ${final_value:.2f}")

# Print the trade log
print("Trade Log:")
for trade in trade_log:
    trade_time, trade_type, trade_price = trade
    print(f"Time: {trade_time}, Trade: {trade_type}, Price: {trade_price:.2f}")
# Out:
# Optimized OU parameters: [ 1.00000000e-06 -5.31030954e+01  5.40587866e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.37167994e+01  5.40588091e-04]
# Optimized OU parameters: [ 1.00000000e-06 -4.14847312e+00  7.01854904e-04]
# Optimized OU parameters: [ 1.00000000e-06 -4.14838231e+00  7.01854904e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.89386261e+00  6.18759426e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.56870017e+00  6.18764031e-04]
# Optimized OU parameters: [ 1.00000000e-06 -4.65991579e+00  5.77891037e-04]
# Optimized OU parameters: [4.99673933e-05 1.64121494e+01 5.77763365e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.45298367e+00  5.62891064e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.49287649e+00  5.62888038e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.22388601e+00  5.47924604e-04]
# Optimized OU parameters: [ 1.00000000e-06 -6.65606294e+00  5.47931352e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.25230330e+00  5.41584544e-04]
# Optimized OU parameters: [ 1.00000000e-06 -9.08439663e+01  5.41603505e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.23874971e+01  5.40591204e-04]
# Optimized OU parameters: [ 1.00000000e-06 -1.09768090e+00  5.40572818e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.24264498e+01  5.40589713e-04]
# Optimized OU parameters: [ 1.00000000e-06 -7.24109471e+00  5.40573531e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.88146769e+03  5.43409996e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.24248426e+00  5.40571926e-04]
# Optimized OU parameters: [ 1.00000000e-06 -1.09767888e+00  5.40569672e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.24338641e+00  5.40571160e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.74613353e+00  5.40570895e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.23992028e+01  5.40588569e-04]
# Optimized OU parameters: [ 1.00000000e-06 -1.15979074e+00  5.40569729e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.30364823e+01  5.40588314e-04]
# Optimized OU parameters: [ 1.00000000e-06 -1.09767888e+00  5.40569672e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.24338641e+00  5.40571160e-04]
# Optimized OU parameters: [ 1.00000000e-06 -4.14847312e+00  7.01854904e-04]
# Optimized OU parameters: [ 1.00000000e-06 -4.14838231e+00  7.01854904e-04]
# Optimized OU parameters: [ 1.00000000e-06 -8.18822442e+02  6.19231041e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.28203297e+00  6.18849116e-04]
# Optimized OU parameters: [ 1.00000000e-06 -1.81640638e+00  5.90112392e-04]
# Optimized OU parameters: [ 1.00000000e-06 -1.15659472e+01  5.90118757e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.23450669e+00  5.47894233e-04]
# Optimized OU parameters: [7.01551281e-04 1.11112648e+00 5.47834755e-04]
# Optimized OU parameters: [ 1.00000000e-06 -3.13309664e+00  5.44433713e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.65330732e+00  5.44433376e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.24047881e+00  5.41939103e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.51848694e+00  5.41938114e-04]
# Optimized OU parameters: [ 1.00000000e-06 -1.67271851e+00  5.41191970e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.24193591e+00  5.41186844e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.23308025e+00  5.40708834e-04]
# Optimized OU parameters: [6.93243292e-04 1.12526377e+00 5.40655804e-04]
# Optimized OU parameters: [ 1.00000000e-06 -8.98294963e+00  5.40644891e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.24251227e+00  5.40643519e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.44058884e+00  5.40609896e-04]
# Optimized OU parameters: [ 1.00000000e-06 -9.01015928e+01  5.40638441e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.23920912e+01  5.40588845e-04]
# Optimized OU parameters: [6.93932510e-04 1.12219064e+00 5.40514879e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.31471793e+00  5.40570722e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.87992465e+00  5.40576895e-04]
# Optimized OU parameters: [ 1.00000000e-06 -1.15974378e+00  5.40569849e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.37915027e+01  5.40588714e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.47067525e+00  5.40571694e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.31471912e+00  5.40570277e-04]
# Optimized OU parameters: [ 1.00000000e-06 -1.44067950e+00  5.40569845e-04]
# Optimized OU parameters: [ 3.54081897e-04 -3.73689668e-01  5.40626559e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.25319138e+00  5.40571171e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.30880480e+01  5.40588315e-04]
# Optimized OU parameters: [ 1.00000000e-06 -1.09752933e+00  5.40569537e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.24337240e+00  5.40571165e-04]
# Optimized OU parameters: [6.93316063e-04 1.12391497e+00 5.40516173e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.31417879e+01  5.40588334e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.30725452e+01  5.40588310e-04]
# Optimized OU parameters: [ 1.00000000e-06 -2.44490238e+00  5.40573102e-04]
# Optimized OU parameters: [6.93237682e-04 1.12425490e+00 5.40517555e-04]
# Optimized OU parameters: [ 1.00000000e-06 -5.37907579e+01  5.40588574e-04]
# Optimized pair ratio B: -0.0000
# Optimized OU parameters: [1.00000000e-06 9.42406392e+01 1.04095870e-03]
# Optimized parameters: mu=0.0000, theta=94.2406, sigma=0.0010
# Optimal exit level b: 94.2354
# Final portfolio value: $100905.95
# Trade Log:
# Time: 106, Trade: BUY, Price: 98.67
# Time: 114, Trade: SELL, Price: 98.70
# Time: 115, Trade: BUY, Price: 98.66
# Time: 116, Trade: SELL, Price: 98.67
# Time: 139, Trade: BUY, Price: 98.68
# Time: 140, Trade: SELL, Price: 98.72
# Time: 146, Trade: BUY, Price: 98.72
# Time: 148, Trade: SELL, Price: 98.76
# Time: 273, Trade: BUY, Price: 100.19
# Time: 290, Trade: SELL, Price: 99.65
# Time: 291, Trade: BUY, Price: 99.62
# Time: 293, Trade: SELL, Price: 99.63
# Time: 297, Trade: BUY, Price: 99.51
# Time: 311, Trade: SELL, Price: 99.39
# Time: 348, Trade: BUY, Price: 99.42
# Time: 349, Trade: SELL, Price: 99.52
# Time: 350, Trade: BUY, Price: 99.42
# Time: 352, Trade: SELL, Price: 99.52
# Time: 353, Trade: BUY, Price: 99.51
# Time: 354, Trade: SELL, Price: 99.56
# Time: 383, Trade: BUY, Price: 99.62
# Time: 385, Trade: SELL, Price: 99.68
# Time: 386, Trade: BUY, Price: 99.67
# Time: 387, Trade: SELL, Price: 99.71
# Time: 388, Trade: BUY, Price: 99.69
# Time: 389, Trade: SELL, Price: 99.71
# Time: 390, Trade: BUY, Price: 99.65
# Time: 395, Trade: SELL, Price: 99.66
# Time: 500, Trade: BUY, Price: 100.24
# Time: 502, Trade: SELL, Price: 100.32
# Time: 511, Trade: BUY, Price: 100.28
# Time: 514, Trade: SELL, Price: 100.29
# Time: 544, Trade: BUY, Price: 100.34
# Time: 545, Trade: SELL, Price: 100.44
# Time: 546, Trade: BUY, Price: 100.37
# Time: 547, Trade: SELL, Price: 100.42
# Time: 553, Trade: BUY, Price: 100.39
# Time: 558, Trade: SELL, Price: 100.44
# Time: 587, Trade: BUY, Price: 100.45
# Time: 588, Trade: SELL, Price: 100.51
# Time: 589, Trade: BUY, Price: 100.45
# Time: 591, Trade: SELL, Price: 100.53
# Time: 596, Trade: BUY, Price: 100.50
# Time: 597, Trade: SELL, Price: 100.51
# Time: 599, Trade: BUY, Price: 100.49
# Time: 600, Trade: SELL, Price: 100.50
# Time: 625, Trade: BUY, Price: 100.52
# Time: 626, Trade: SELL, Price: 100.54
# Time: 628, Trade: BUY, Price: 100.52
# Time: 629, Trade: SELL, Price: 100.53
# Time: 631, Trade: BUY, Price: 99.87
# Time: 650, Trade: SELL, Price: 99.58
# Time: 651, Trade: BUY, Price: 99.45
# Time: 652, Trade: SELL, Price: 99.54
# Time: 676, Trade: BUY, Price: 99.43
# Time: 677, Trade: SELL, Price: 99.50
# Time: 679, Trade: BUY, Price: 99.47
# Time: 680, Trade: SELL, Price: 99.52
# Time: 733, Trade: BUY, Price: 99.82
# Time: 735, Trade: SELL, Price: 99.88
# Time: 737, Trade: BUY, Price: 99.82
# Time: 738, Trade: SELL, Price: 99.88
# Time: 774, Trade: BUY, Price: 100.02
# Time: 778, Trade: SELL, Price: 100.14
# Time: 780, Trade: BUY, Price: 100.11
# Time: 781, Trade: SELL, Price: 100.14
# Time: 784, Trade: BUY, Price: 100.10
# Time: 832, Trade: SELL, Price: 99.10
# Time: 837, Trade: BUY, Price: 98.95
# Time: 841, Trade: SELL, Price: 98.95
# Time: 922, Trade: BUY, Price: 99.68
# Time: 928, Trade: SELL, Price: 99.75
# Time: 931, Trade: BUY, Price: 99.67
# Time: 949, Trade: SELL, Price: 99.38
# Time: 961, Trade: BUY, Price: 99.27
# Time: 976, Trade: SELL, Price: 99.07
# Time: 1015, Trade: BUY, Price: 98.93
# Time: 1021, Trade: SELL, Price: 99.04
# Time: 1022, Trade: BUY, Price: 99.02
# Time: 1023, Trade: SELL, Price: 99.08
# Time: 1027, Trade: BUY, Price: 99.01
# Time: 1028, Trade: SELL, Price: 99.06
# Time: 1046, Trade: BUY, Price: 99.00
# Time: 1048, Trade: SELL, Price: 99.07
# Time: 1077, Trade: BUY, Price: 99.08
# Time: 1081, Trade: SELL, Price: 99.23
# Time: 1117, Trade: BUY, Price: 99.28
# Time: 1125, Trade: SELL, Price: 99.25
# Time: 1157, Trade: BUY, Price: 99.28
# Time: 1158, Trade: SELL, Price: 99.32
# Time: 1199, Trade: BUY, Price: 99.46
# Time: 1200, Trade: SELL, Price: 99.47
# Time: 1201, Trade: BUY, Price: 99.40
# Time: 1203, Trade: SELL, Price: 99.52
# Time: 1204, Trade: BUY, Price: 99.44
# Time: 1209, Trade: SELL, Price: 99.45
# Time: 1218, Trade: BUY, Price: 99.40
# Time: 1231, Trade: SELL, Price: 99.31
# Time: 1238, Trade: BUY, Price: 99.26
# Time: 1239, Trade: SELL, Price: 99.29
# Time: 1246, Trade: BUY, Price: 99.22
# Time: 1259, Trade: SELL, Price: 98.69
# Time: 1311, Trade: BUY, Price: 99.07
# Time: 1312, Trade: SELL, Price: 99.18
# Time: 1331, Trade: BUY, Price: 99.16
# Time: 1333, Trade: SELL, Price: 99.25
# Time: 1368, Trade: BUY, Price: 99.45
# Time: 1375, Trade: SELL, Price: 99.51
# Time: 1394, Trade: BUY, Price: 99.48
# Time: 1395, Trade: SELL, Price: 99.54
# Time: 1461, Trade: BUY, Price: 99.82
# Time: 1465, Trade: SELL, Price: 99.89
# Time: 1467, Trade: BUY, Price: 99.83
# Time: 1468, Trade: SELL, Price: 99.87
# Time: 1471, Trade: BUY, Price: 99.78
# Time: 1476, Trade: SELL, Price: 99.84
# Time: 1529, Trade: BUY, Price: 100.30
# Time: 1530, Trade: SELL, Price: 100.35
# Time: 1565, Trade: BUY, Price: 100.69
# Time: 1568, Trade: SELL, Price: 100.74
# Time: 1569, Trade: BUY, Price: 100.68
# Time: 1576, Trade: SELL, Price: 100.68
# Time: 1582, Trade: BUY, Price: 100.65
# Time: 1584, Trade: SELL, Price: 100.71
# Time: 1586, Trade: BUY, Price: 100.65
# Time: 1596, Trade: SELL, Price: 100.59
# Time: 1676, Trade: BUY, Price: 101.16
# Time: 1684, Trade: SELL, Price: 101.20
# Time: 1685, Trade: BUY, Price: 101.11
# Time: 1687, Trade: SELL, Price: 101.16
# Time: 1834, Trade: BUY, Price: 102.52
# Time: 1841, Trade: SELL, Price: 103.18
# Time: 1843, Trade: BUY, Price: 102.90
# Time: 1853, Trade: SELL, Price: 102.21
# Time: 1882, Trade: BUY, Price: 102.17
# Time: 1883, Trade: SELL, Price: 102.37
# Time: 1891, Trade: BUY, Price: 102.35
# Time: 1895, Trade: SELL, Price: 102.49
# Time: 1921, Trade: BUY, Price: 102.46
# Time: 1922, Trade: SELL, Price: 102.53
# Time: 1923, Trade: BUY, Price: 102.43
# Time: 1928, Trade: SELL, Price: 102.48
# Time: 1929, Trade: BUY, Price: 102.43
# Time: 1939, Trade: SELL, Price: 102.37
# Time: 1966, Trade: BUY, Price: 102.21
# Time: 1980, Trade: SELL, Price: 102.20
# Time: 1990, Trade: BUY, Price: 102.16
# Time: 1991, Trade: SELL, Price: 102.19
# Time: 1994, Trade: BUY, Price: 102.14
# Time: 1997, Trade: SELL, Price: 102.16
# Time: 1998, Trade: BUY, Price: 102.12
# Time: 2003, Trade: SELL, Price: 102.14
# Time: 2007, Trade: BUY, Price: 102.10
# Time: 2011, Trade: SELL, Price: 102.11
# Time: 2059, Trade: BUY, Price: 102.27
# Time: 2063, Trade: SELL, Price: 102.34
# Time: 2064, Trade: BUY, Price: 102.27
# Time: 2065, Trade: SELL, Price: 102.33
# Time: 2067, Trade: BUY, Price: 101.13
# Time: 2076, Trade: SELL, Price: 101.54
# Time: 2102, Trade: BUY, Price: 101.55
# Time: 2103, Trade: SELL, Price: 101.69
# Time: 2104, Trade: BUY, Price: 101.58
# Time: 2109, Trade: SELL, Price: 101.70
# Time: 2111, Trade: BUY, Price: 101.63
# Time: 2145, Trade: SELL, Price: 100.83
# Time: 2148, Trade: BUY, Price: 100.66
# Time: 2154, Trade: SELL, Price: 100.64
# Time: 2156, Trade: BUY, Price: 100.52
# Time: 2158, Trade: SELL, Price: 100.69
# Time: 2171, Trade: BUY, Price: 100.58
# Time: 2172, Trade: SELL, Price: 100.62
# Time: 2173, Trade: BUY, Price: 100.56
# Time: 2174, Trade: SELL, Price: 100.69
# Time: 2179, Trade: BUY, Price: 100.56
# Time: 2181, Trade: SELL, Price: 100.60
# Time: 2191, Trade: BUY, Price: 100.51
# Time: 2193, Trade: SELL, Price: 100.60
# Time: 2194, Trade: BUY, Price: 100.55
# Time: 2195, Trade: SELL, Price: 100.65
# Time: 2259, Trade: BUY, Price: 101.00
# Time: 2260, Trade: SELL, Price: 101.10
# Time: 2348, Trade: BUY, Price: 101.91
# Time: 2349, Trade: SELL, Price: 101.94
# Time: 2352, Trade: BUY, Price: 101.93
# Time: 2353, Trade: SELL, Price: 101.93
# Time: 2386, Trade: BUY, Price: 102.01
# Time: 2398, Trade: SELL, Price: 101.90
# Time: 2430, Trade: BUY, Price: 102.00
# Time: 2438, Trade: SELL, Price: 102.02
# Time: 2454, Trade: BUY, Price: 101.98
# Time: 2455, Trade: SELL, Price: 101.99
# Time: 2457, Trade: BUY, Price: 101.98
# Time: 2459, Trade: SELL, Price: 102.01
# Time: 2461, Trade: BUY, Price: 101.95
# Time: 2464, Trade: SELL, Price: 102.02
# Time: 2465, Trade: BUY, Price: 101.95
# Time: 2466, Trade: SELL, Price: 102.02
# Time: 2471, Trade: BUY, Price: 101.96
# Time: 2472, Trade: SELL, Price: 101.98
# Time: 2552, Trade: BUY, Price: 102.20
# Time: 2556, Trade: SELL, Price: 102.26
# Time: 2645, Trade: BUY, Price: 102.82
# Time: 2648, Trade: SELL, Price: 102.90
# Time: 2651, Trade: BUY, Price: 102.84
# Time: 2652, Trade: SELL, Price: 102.87
# Time: 2656, Trade: BUY, Price: 102.82
# Time: 2659, Trade: SELL, Price: 102.85
# Time: 2660, Trade: BUY, Price: 102.81
# Time: 2661, Trade: SELL, Price: 102.85
# Time: 2662, Trade: BUY, Price: 102.82
# Time: 2663, Trade: SELL, Price: 102.88
# Time: 2695, Trade: BUY, Price: 102.86
# Time: 2696, Trade: SELL, Price: 102.92
# Time: 2704, Trade: BUY, Price: 102.91
# Time: 2707, Trade: SELL, Price: 102.92
# Time: 2708, Trade: BUY, Price: 102.88
# Time: 2709, Trade: SELL, Price: 102.93
# Time: 2729, Trade: BUY, Price: 102.88
# Time: 2737, Trade: SELL, Price: 102.86
# Time: 2747, Trade: BUY, Price: 102.69
# Time: 2754, Trade: SELL, Price: 102.76
# Time: 2856, Trade: BUY, Price: 103.22
# Time: 2859, Trade: SELL, Price: 103.26
# Time: 2861, Trade: BUY, Price: 103.23
# Time: 2862, Trade: SELL, Price: 103.32
# Time: 2962, Trade: BUY, Price: 103.69
# Time: 2983, Trade: SELL, Price: 103.58
# Time: 2984, Trade: BUY, Price: 103.33
# Time: 2985, Trade: SELL, Price: 103.40
# Time: 2988, Trade: BUY, Price: 103.35
# Time: 2989, Trade: SELL, Price: 103.39
# Time: 3022, Trade: BUY, Price: 103.48
# Time: 3024, Trade: SELL, Price: 103.52
# Time: 3025, Trade: BUY, Price: 103.38
# Time: 3042, Trade: SELL, Price: 103.11
# Time: 3043, Trade: BUY, Price: 103.04
# Time: 3051, Trade: SELL, Price: 103.01
# Time: 3155, Trade: BUY, Price: 103.77
# Time: 3168, Trade: SELL, Price: 103.69
# Time: 3243, Trade: BUY, Price: 104.29
# Time: 3257, Trade: SELL, Price: 104.24
# Time: 3260, Trade: BUY, Price: 104.18
# Time: 3270, Trade: SELL, Price: 104.12
# Time: 3302, Trade: BUY, Price: 104.15
# Time: 3305, Trade: SELL, Price: 104.20
# Time: 3321, Trade: BUY, Price: 104.03
# Time: 3324, Trade: SELL, Price: 104.17
# Time: 3325, Trade: BUY, Price: 104.13
# Time: 3328, Trade: SELL, Price: 104.15
# Time: 3330, Trade: BUY, Price: 104.11
# Time: 3331, Trade: SELL, Price: 104.16
# Time: 3335, Trade: BUY, Price: 104.11
# Time: 3342, Trade: SELL, Price: 104.06
# Time: 3345, Trade: BUY, Price: 104.02
# Time: 3346, Trade: SELL, Price: 104.09
# Time: 3372, Trade: BUY, Price: 104.02
# Time: 3374, Trade: SELL, Price: 104.13
# Time: 3376, Trade: BUY, Price: 104.03
# Time: 3382, Trade: SELL, Price: 104.13
# Time: 3434, Trade: BUY, Price: 104.14
# Time: 3435, Trade: SELL, Price: 104.19
# Time: 3436, Trade: BUY, Price: 104.15
# Time: 3438, Trade: SELL, Price: 104.20
# Time: 3440, Trade: BUY, Price: 104.16
# Time: 3442, Trade: SELL, Price: 104.21
# Time: 3454, Trade: BUY, Price: 104.12
# Time: 3474, Trade: SELL, Price: 103.94
# Time: 3475, Trade: BUY, Price: 103.91
# Time: 3476, Trade: SELL, Price: 103.93
# Time: 3477, Trade: BUY, Price: 103.88
# Time: 3487, Trade: SELL, Price: 103.69
# Time: 3529, Trade: BUY, Price: 103.74
# Time: 3534, Trade: SELL, Price: 103.77
# Time: 3570, Trade: BUY, Price: 103.97
# Time: 3585, Trade: SELL, Price: 103.66
# Time: 3598, Trade: BUY, Price: 103.55
# Time: 3599, Trade: SELL, Price: 103.63
# Time: 3608, Trade: BUY, Price: 103.57
# Time: 3614, Trade: SELL, Price: 103.65
# Time: 3689, Trade: BUY, Price: 103.98
# Time: 3696, Trade: SELL, Price: 103.97
# Time: 3697, Trade: BUY, Price: 103.95
# Time: 3699, Trade: SELL, Price: 104.02
# Time: 3776, Trade: BUY, Price: 104.38
# Time: 3777, Trade: SELL, Price: 104.40
# Time: 3778, Trade: BUY, Price: 104.38
# Time: 3779, Trade: SELL, Price: 104.41
# Time: 3787, Trade: BUY, Price: 104.39
# Time: 3788, Trade: SELL, Price: 104.43
# Time: 3789, Trade: BUY, Price: 104.39
# Time: 3790, Trade: SELL, Price: 104.42
# Time: 3822, Trade: BUY, Price: 104.45
# Time: 3823, Trade: SELL, Price: 104.47
# Time: 3829, Trade: BUY, Price: 104.43
# Time: 3831, Trade: SELL, Price: 104.50
# Time: 3844, Trade: BUY, Price: 104.42
# Time: 3845, Trade: SELL, Price: 104.52
# Time: 3861, Trade: BUY, Price: 104.43
# Time: 3863, Trade: SELL, Price: 104.48
# Time: 3864, Trade: BUY, Price: 104.45
# Time: 3867, Trade: SELL, Price: 104.52
# Time: 3885, Trade: BUY, Price: 104.47
# Time: 3886, Trade: SELL, Price: 104.53
# Time: 3904, Trade: BUY, Price: 104.51
# Time: 3908, Trade: SELL, Price: 104.54
# Time: 3918, Trade: BUY, Price: 104.48
# Time: 3938, Trade: SELL, Price: 104.29
# Time: 3939, Trade: BUY, Price: 104.24
# Time: 3942, Trade: SELL, Price: 104.28
# Time: 3966, Trade: BUY, Price: 104.21
# Time: 3977, Trade: SELL, Price: 104.25
# Time: 3978, Trade: BUY, Price: 104.10
# Time: 4008, Trade: SELL, Price: 103.64
# Time: 4062, Trade: BUY, Price: 103.98
# Time: 4066, Trade: SELL, Price: 104.02
# Time: 4068, Trade: BUY, Price: 104.00
# Time: 4071, Trade: SELL, Price: 104.05
# Time: 4075, Trade: BUY, Price: 103.99
# Time: 4076, Trade: SELL, Price: 104.03
# Time: 4079, Trade: BUY, Price: 103.94
# Time: 4084, Trade: SELL, Price: 103.97
# Time: 4094, Trade: BUY, Price: 103.93
# Time: 4095, Trade: SELL, Price: 104.05
# Time: 4131, Trade: BUY, Price: 104.30
# Time: 4132, Trade: SELL, Price: 104.51
# Time: 4134, Trade: BUY, Price: 104.38
# Time: 4139, Trade: SELL, Price: 104.41
# Time: 4140, Trade: BUY, Price: 104.38
# Time: 4141, Trade: SELL, Price: 104.43

# %% [markdown]
# ### 6 - Results

# %%
# Calculate daily returns
def calculate_daily_returns(portfolio_values):
    returns = np.diff(portfolio_values) / portfolio_values[:-1]
    return returns

# Calculate Sharpe ratio
def calculate_sharpe_ratio(returns, risk_free_rate=0.0):
    mean_return = np.mean(returns)
    std_return = np.std(returns)
    sharpe_ratio = (mean_return - risk_free_rate) / std_return
    return sharpe_ratio

# Calculate gain or loss for each trade and track win/loss performance
def calculate_trade_performance(trade_log):
    trade_performance = []
    for i in range(0, len(trade_log), 2):
        if i + 1 < len(trade_log):
            buy_trade = trade_log[i]
            sell_trade = trade_log[i + 1]
            gain_or_loss = (sell_trade[2] - buy_trade[2]) * 50000 / buy_trade[2]
            performance = 'Win' if gain_or_loss > 0 else 'Loss'
            trade_performance.append((buy_trade, sell_trade, gain_or_loss, performance))
    return trade_performance

# Calculate overall win rate
def calculate_win_rate(trade_performance):
    wins = sum(1 for trade in trade_performance if trade[3] == 'Win')
    total_trades = len(trade_performance)
    win_rate = wins / total_trades if total_trades > 0 else 0
    return win_rate

# Final summary
def final_summary(portfolio_values, trade_log):
    initial_value = portfolio_values[0]
    final_value = portfolio_values[-1]
    total_return = (final_value - initial_value) / initial_value
    daily_returns = calculate_daily_returns(portfolio_values)
    sharpe_ratio = calculate_sharpe_ratio(daily_returns)
    trade_performance = calculate_trade_performance(trade_log)
    win_rate = calculate_win_rate(trade_performance)

    print(f"Final portfolio value: ${final_value:.2f}")
    print(f"Total return: {total_return * 100:.2f}%")
    print(f"Sharpe ratio: {sharpe_ratio:.2f}")
    print(f"Win rate: {win_rate * 100:.2f}%")
    print("Trade Performance Log:")
    for trade in trade_performance:
        buy_trade, sell_trade, gain_or_loss, performance = trade
        print(f"Buy Time: {buy_trade[0]}, Sell Time: {sell_trade[0]}, Buy Price: {buy_trade[2]:.2f}, Sell Price: {sell_trade[2]:.2f}, Gain/Loss: {gain_or_loss:.2f}, Performance: {performance}")

# Print the final summary
final_summary(portfolio_simulation, trade_log)
# Out:
# Final portfolio value: $100905.95
# Total return: 0.91%
# Sharpe ratio: 0.01
# Win rate: 81.21%
# Trade Performance Log:
# Buy Time: 106, Sell Time: 114, Buy Price: 98.67, Sell Price: 98.70, Gain/Loss: 14.95, Performance: Win
# Buy Time: 115, Sell Time: 116, Buy Price: 98.66, Sell Price: 98.67, Gain/Loss: 7.86, Performance: Win
# Buy Time: 139, Sell Time: 140, Buy Price: 98.68, Sell Price: 98.72, Gain/Loss: 23.82, Performance: Win
# Buy Time: 146, Sell Time: 148, Buy Price: 98.72, Sell Price: 98.76, Gain/Loss: 20.26, Performance: Win
# Buy Time: 273, Sell Time: 290, Buy Price: 100.19, Sell Price: 99.65, Gain/Loss: -271.72, Performance: Loss
# Buy Time: 291, Sell Time: 293, Buy Price: 99.62, Sell Price: 99.63, Gain/Loss: 5.52, Performance: Win
# Buy Time: 297, Sell Time: 311, Buy Price: 99.51, Sell Price: 99.39, Gain/Loss: -61.05, Performance: Loss
# Buy Time: 348, Sell Time: 349, Buy Price: 99.42, Sell Price: 99.52, Gain/Loss: 53.06, Performance: Win
# Buy Time: 350, Sell Time: 352, Buy Price: 99.42, Sell Price: 99.52, Gain/Loss: 49.28, Performance: Win
# Buy Time: 353, Sell Time: 354, Buy Price: 99.51, Sell Price: 99.56, Gain/Loss: 25.38, Performance: Win
# Buy Time: 383, Sell Time: 385, Buy Price: 99.62, Sell Price: 99.68, Gain/Loss: 32.62, Performance: Win
# Buy Time: 386, Sell Time: 387, Buy Price: 99.67, Sell Price: 99.71, Gain/Loss: 17.06, Performance: Win
# Buy Time: 388, Sell Time: 389, Buy Price: 99.69, Sell Price: 99.71, Gain/Loss: 11.29, Performance: Win
# Buy Time: 390, Sell Time: 395, Buy Price: 99.65, Sell Price: 99.66, Gain/Loss: 1.76, Performance: Win
# Buy Time: 500, Sell Time: 502, Buy Price: 100.24, Sell Price: 100.32, Gain/Loss: 43.15, Performance: Win
# Buy Time: 511, Sell Time: 514, Buy Price: 100.28, Sell Price: 100.29, Gain/Loss: 7.98, Performance: Win
# Buy Time: 544, Sell Time: 545, Buy Price: 100.34, Sell Price: 100.44, Gain/Loss: 51.33, Performance: Win
# Buy Time: 546, Sell Time: 547, Buy Price: 100.37, Sell Price: 100.42, Gain/Loss: 22.67, Performance: Win
# Buy Time: 553, Sell Time: 558, Buy Price: 100.39, Sell Price: 100.44, Gain/Loss: 24.65, Performance: Win
# Buy Time: 587, Sell Time: 588, Buy Price: 100.45, Sell Price: 100.51, Gain/Loss: 26.88, Performance: Win
# Buy Time: 589, Sell Time: 591, Buy Price: 100.45, Sell Price: 100.53, Gain/Loss: 39.57, Performance: Win
# Buy Time: 596, Sell Time: 597, Buy Price: 100.50, Sell Price: 100.51, Gain/Loss: 3.98, Performance: Win
# Buy Time: 599, Sell Time: 600, Buy Price: 100.49, Sell Price: 100.50, Gain/Loss: 3.73, Performance: Win
# Buy Time: 625, Sell Time: 626, Buy Price: 100.52, Sell Price: 100.54, Gain/Loss: 6.22, Performance: Win
# Buy Time: 628, Sell Time: 629, Buy Price: 100.52, Sell Price: 100.53, Gain/Loss: 6.72, Performance: Win
# Buy Time: 631, Sell Time: 650, Buy Price: 99.87, Sell Price: 99.58, Gain/Loss: -147.69, Performance: Loss
# Buy Time: 651, Sell Time: 652, Buy Price: 99.45, Sell Price: 99.54, Gain/Loss: 44.24, Performance: Win
# Buy Time: 676, Sell Time: 677, Buy Price: 99.43, Sell Price: 99.50, Gain/Loss: 32.43, Performance: Win
# Buy Time: 679, Sell Time: 680, Buy Price: 99.47, Sell Price: 99.52, Gain/Loss: 22.37, Performance: Win
# Buy Time: 733, Sell Time: 735, Buy Price: 99.82, Sell Price: 99.88, Gain/Loss: 28.80, Performance: Win
# Buy Time: 737, Sell Time: 738, Buy Price: 99.82, Sell Price: 99.88, Gain/Loss: 26.05, Performance: Win
# Buy Time: 774, Sell Time: 778, Buy Price: 100.02, Sell Price: 100.14, Gain/Loss: 58.99, Performance: Win
# Buy Time: 780, Sell Time: 781, Buy Price: 100.11, Sell Price: 100.14, Gain/Loss: 10.99, Performance: Win
# Buy Time: 784, Sell Time: 832, Buy Price: 100.10, Sell Price: 99.10, Gain/Loss: -499.24, Performance: Loss
# Buy Time: 837, Sell Time: 841, Buy Price: 98.95, Sell Price: 98.95, Gain/Loss: -1.77, Performance: Loss
# Buy Time: 922, Sell Time: 928, Buy Price: 99.68, Sell Price: 99.75, Gain/Loss: 33.61, Performance: Win
# Buy Time: 931, Sell Time: 949, Buy Price: 99.67, Sell Price: 99.38, Gain/Loss: -146.23, Performance: Loss
# Buy Time: 961, Sell Time: 976, Buy Price: 99.27, Sell Price: 99.07, Gain/Loss: -102.75, Performance: Loss
# Buy Time: 1015, Sell Time: 1021, Buy Price: 98.93, Sell Price: 99.04, Gain/Loss: 58.38, Performance: Win
# Buy Time: 1022, Sell Time: 1023, Buy Price: 99.02, Sell Price: 99.08, Gain/Loss: 26.26, Performance: Win
# Buy Time: 1027, Sell Time: 1028, Buy Price: 99.01, Sell Price: 99.06, Gain/Loss: 24.74, Performance: Win
# Buy Time: 1046, Sell Time: 1048, Buy Price: 99.00, Sell Price: 99.07, Gain/Loss: 36.11, Performance: Win
# Buy Time: 1077, Sell Time: 1081, Buy Price: 99.08, Sell Price: 99.23, Gain/Loss: 75.45, Performance: Win
# Buy Time: 1117, Sell Time: 1125, Buy Price: 99.28, Sell Price: 99.25, Gain/Loss: -12.09, Performance: Loss
# Buy Time: 1157, Sell Time: 1158, Buy Price: 99.28, Sell Price: 99.32, Gain/Loss: 17.37, Performance: Win
# Buy Time: 1199, Sell Time: 1200, Buy Price: 99.46, Sell Price: 99.47, Gain/Loss: 5.28, Performance: Win
# Buy Time: 1201, Sell Time: 1203, Buy Price: 99.40, Sell Price: 99.52, Gain/Loss: 57.34, Performance: Win
# Buy Time: 1204, Sell Time: 1209, Buy Price: 99.44, Sell Price: 99.45, Gain/Loss: 1.76, Performance: Win
# Buy Time: 1218, Sell Time: 1231, Buy Price: 99.40, Sell Price: 99.31, Gain/Loss: -45.77, Performance: Loss
# Buy Time: 1238, Sell Time: 1239, Buy Price: 99.26, Sell Price: 99.29, Gain/Loss: 15.11, Performance: Win
# Buy Time: 1246, Sell Time: 1259, Buy Price: 99.22, Sell Price: 98.69, Gain/Loss: -267.35, Performance: Loss
# Buy Time: 1311, Sell Time: 1312, Buy Price: 99.07, Sell Price: 99.18, Gain/Loss: 55.01, Performance: Win
# Buy Time: 1331, Sell Time: 1333, Buy Price: 99.16, Sell Price: 99.25, Gain/Loss: 48.41, Performance: Win
# Buy Time: 1368, Sell Time: 1375, Buy Price: 99.45, Sell Price: 99.51, Gain/Loss: 32.93, Performance: Win
# Buy Time: 1394, Sell Time: 1395, Buy Price: 99.48, Sell Price: 99.54, Gain/Loss: 29.40, Performance: Win
# Buy Time: 1461, Sell Time: 1465, Buy Price: 99.82, Sell Price: 99.89, Gain/Loss: 33.31, Performance: Win
# Buy Time: 1467, Sell Time: 1468, Buy Price: 99.83, Sell Price: 99.87, Gain/Loss: 23.54, Performance: Win
# Buy Time: 1471, Sell Time: 1476, Buy Price: 99.78, Sell Price: 99.84, Gain/Loss: 30.82, Performance: Win
# Buy Time: 1529, Sell Time: 1530, Buy Price: 100.30, Sell Price: 100.35, Gain/Loss: 24.68, Performance: Win
# Buy Time: 1565, Sell Time: 1568, Buy Price: 100.69, Sell Price: 100.74, Gain/Loss: 24.58, Performance: Win
# Buy Time: 1569, Sell Time: 1576, Buy Price: 100.68, Sell Price: 100.68, Gain/Loss: 1.99, Performance: Win
# Buy Time: 1582, Sell Time: 1584, Buy Price: 100.65, Sell Price: 100.71, Gain/Loss: 26.33, Performance: Win
# Buy Time: 1586, Sell Time: 1596, Buy Price: 100.65, Sell Price: 100.59, Gain/Loss: -30.30, Performance: Loss
# Buy Time: 1676, Sell Time: 1684, Buy Price: 101.16, Sell Price: 101.20, Gain/Loss: 21.01, Performance: Win
# Buy Time: 1685, Sell Time: 1687, Buy Price: 101.11, Sell Price: 101.16, Gain/Loss: 27.69, Performance: Win
# Buy Time: 1834, Sell Time: 1841, Buy Price: 102.52, Sell Price: 103.18, Gain/Loss: 322.38, Performance: Win
# Buy Time: 1843, Sell Time: 1853, Buy Price: 102.90, Sell Price: 102.21, Gain/Loss: -332.13, Performance: Loss
# Buy Time: 1882, Sell Time: 1883, Buy Price: 102.17, Sell Price: 102.37, Gain/Loss: 99.10, Performance: Win
# Buy Time: 1891, Sell Time: 1895, Buy Price: 102.35, Sell Price: 102.49, Gain/Loss: 68.39, Performance: Win
# Buy Time: 1921, Sell Time: 1922, Buy Price: 102.46, Sell Price: 102.53, Gain/Loss: 35.38, Performance: Win
# Buy Time: 1923, Sell Time: 1928, Buy Price: 102.43, Sell Price: 102.48, Gain/Loss: 22.70, Performance: Win
# Buy Time: 1929, Sell Time: 1939, Buy Price: 102.43, Sell Price: 102.37, Gain/Loss: -30.02, Performance: Loss
# Buy Time: 1966, Sell Time: 1980, Buy Price: 102.21, Sell Price: 102.20, Gain/Loss: -4.40, Performance: Loss
# Buy Time: 1990, Sell Time: 1991, Buy Price: 102.16, Sell Price: 102.19, Gain/Loss: 16.15, Performance: Win
# Buy Time: 1994, Sell Time: 1997, Buy Price: 102.14, Sell Price: 102.16, Gain/Loss: 6.61, Performance: Win
# Buy Time: 1998, Sell Time: 2003, Buy Price: 102.12, Sell Price: 102.14, Gain/Loss: 9.30, Performance: Win
# Buy Time: 2007, Sell Time: 2011, Buy Price: 102.10, Sell Price: 102.11, Gain/Loss: 1.22, Performance: Win
# Buy Time: 2059, Sell Time: 2063, Buy Price: 102.27, Sell Price: 102.34, Gain/Loss: 32.76, Performance: Win
# Buy Time: 2064, Sell Time: 2065, Buy Price: 102.27, Sell Price: 102.33, Gain/Loss: 29.82, Performance: Win
# Buy Time: 2067, Sell Time: 2076, Buy Price: 101.13, Sell Price: 101.54, Gain/Loss: 206.67, Performance: Win
# Buy Time: 2102, Sell Time: 2103, Buy Price: 101.55, Sell Price: 101.69, Gain/Loss: 66.22, Performance: Win
# Buy Time: 2104, Sell Time: 2109, Buy Price: 101.58, Sell Price: 101.70, Gain/Loss: 61.04, Performance: Win
# Buy Time: 2111, Sell Time: 2145, Buy Price: 101.63, Sell Price: 100.83, Gain/Loss: -391.62, Performance: Loss
# Buy Time: 2148, Sell Time: 2154, Buy Price: 100.66, Sell Price: 100.64, Gain/Loss: -11.67, Performance: Loss
# Buy Time: 2156, Sell Time: 2158, Buy Price: 100.52, Sell Price: 100.69, Gain/Loss: 86.06, Performance: Win
# Buy Time: 2171, Sell Time: 2172, Buy Price: 100.58, Sell Price: 100.62, Gain/Loss: 20.38, Performance: Win
# Buy Time: 2173, Sell Time: 2174, Buy Price: 100.56, Sell Price: 100.69, Gain/Loss: 64.39, Performance: Win
# Buy Time: 2179, Sell Time: 2181, Buy Price: 100.56, Sell Price: 100.60, Gain/Loss: 20.63, Performance: Win
# Buy Time: 2191, Sell Time: 2193, Buy Price: 100.51, Sell Price: 100.60, Gain/Loss: 49.00, Performance: Win
# Buy Time: 2194, Sell Time: 2195, Buy Price: 100.55, Sell Price: 100.65, Gain/Loss: 53.21, Performance: Win
# Buy Time: 2259, Sell Time: 2260, Buy Price: 101.00, Sell Price: 101.10, Gain/Loss: 48.51, Performance: Win
# Buy Time: 2348, Sell Time: 2349, Buy Price: 101.91, Sell Price: 101.94, Gain/Loss: 12.51, Performance: Win
# Buy Time: 2352, Sell Time: 2353, Buy Price: 101.93, Sell Price: 101.93, Gain/Loss: 2.70, Performance: Win
# Buy Time: 2386, Sell Time: 2398, Buy Price: 102.01, Sell Price: 101.90, Gain/Loss: -54.16, Performance: Loss
# Buy Time: 2430, Sell Time: 2438, Buy Price: 102.00, Sell Price: 102.02, Gain/Loss: 12.26, Performance: Win
# Buy Time: 2454, Sell Time: 2455, Buy Price: 101.98, Sell Price: 101.99, Gain/Loss: 6.37, Performance: Win
# Buy Time: 2457, Sell Time: 2459, Buy Price: 101.98, Sell Price: 102.01, Gain/Loss: 14.71, Performance: Win
# Buy Time: 2461, Sell Time: 2464, Buy Price: 101.95, Sell Price: 102.02, Gain/Loss: 34.08, Performance: Win
# Buy Time: 2465, Sell Time: 2466, Buy Price: 101.95, Sell Price: 102.02, Gain/Loss: 35.31, Performance: Win
# Buy Time: 2471, Sell Time: 2472, Buy Price: 101.96, Sell Price: 101.98, Gain/Loss: 10.05, Performance: Win
# Buy Time: 2552, Sell Time: 2556, Buy Price: 102.20, Sell Price: 102.26, Gain/Loss: 27.40, Performance: Win
# Buy Time: 2645, Sell Time: 2648, Buy Price: 102.82, Sell Price: 102.90, Gain/Loss: 36.96, Performance: Win
# Buy Time: 2651, Sell Time: 2652, Buy Price: 102.84, Sell Price: 102.87, Gain/Loss: 17.75, Performance: Win
# Buy Time: 2656, Sell Time: 2659, Buy Price: 102.82, Sell Price: 102.85, Gain/Loss: 15.80, Performance: Win
# Buy Time: 2660, Sell Time: 2661, Buy Price: 102.81, Sell Price: 102.85, Gain/Loss: 16.05, Performance: Win
# Buy Time: 2662, Sell Time: 2663, Buy Price: 102.82, Sell Price: 102.88, Gain/Loss: 27.96, Performance: Win
# Buy Time: 2695, Sell Time: 2696, Buy Price: 102.86, Sell Price: 102.92, Gain/Loss: 26.49, Performance: Win
# Buy Time: 2704, Sell Time: 2707, Buy Price: 102.91, Sell Price: 102.92, Gain/Loss: 5.83, Performance: Win
# Buy Time: 2708, Sell Time: 2709, Buy Price: 102.88, Sell Price: 102.93, Gain/Loss: 23.33, Performance: Win
# Buy Time: 2729, Sell Time: 2737, Buy Price: 102.88, Sell Price: 102.86, Gain/Loss: -11.91, Performance: Loss
# Buy Time: 2747, Sell Time: 2754, Buy Price: 102.69, Sell Price: 102.76, Gain/Loss: 34.33, Performance: Win
# Buy Time: 2856, Sell Time: 2859, Buy Price: 103.22, Sell Price: 103.26, Gain/Loss: 19.13, Performance: Win
# Buy Time: 2861, Sell Time: 2862, Buy Price: 103.23, Sell Price: 103.32, Gain/Loss: 39.47, Performance: Win
# Buy Time: 2962, Sell Time: 2983, Buy Price: 103.69, Sell Price: 103.58, Gain/Loss: -56.42, Performance: Loss
# Buy Time: 2984, Sell Time: 2985, Buy Price: 103.33, Sell Price: 103.40, Gain/Loss: 31.21, Performance: Win
# Buy Time: 2988, Sell Time: 2989, Buy Price: 103.35, Sell Price: 103.39, Gain/Loss: 18.63, Performance: Win
# Buy Time: 3022, Sell Time: 3024, Buy Price: 103.48, Sell Price: 103.52, Gain/Loss: 15.22, Performance: Win
# Buy Time: 3025, Sell Time: 3042, Buy Price: 103.38, Sell Price: 103.11, Gain/Loss: -128.65, Performance: Loss
# Buy Time: 3043, Sell Time: 3051, Buy Price: 103.04, Sell Price: 103.01, Gain/Loss: -17.23, Performance: Loss
# Buy Time: 3155, Sell Time: 3168, Buy Price: 103.77, Sell Price: 103.69, Gain/Loss: -36.14, Performance: Loss
# Buy Time: 3243, Sell Time: 3257, Buy Price: 104.29, Sell Price: 104.24, Gain/Loss: -24.69, Performance: Loss
# Buy Time: 3260, Sell Time: 3270, Buy Price: 104.18, Sell Price: 104.12, Gain/Loss: -24.96, Performance: Loss
# Buy Time: 3302, Sell Time: 3305, Buy Price: 104.15, Sell Price: 104.20, Gain/Loss: 27.37, Performance: Win
# Buy Time: 3321, Sell Time: 3324, Buy Price: 104.03, Sell Price: 104.17, Gain/Loss: 65.37, Performance: Win
# Buy Time: 3325, Sell Time: 3328, Buy Price: 104.13, Sell Price: 104.15, Gain/Loss: 12.72, Performance: Win
# Buy Time: 3330, Sell Time: 3331, Buy Price: 104.11, Sell Price: 104.16, Gain/Loss: 24.01, Performance: Win
# Buy Time: 3335, Sell Time: 3342, Buy Price: 104.11, Sell Price: 104.06, Gain/Loss: -22.33, Performance: Loss
# Buy Time: 3345, Sell Time: 3346, Buy Price: 104.02, Sell Price: 104.09, Gain/Loss: 31.72, Performance: Win
# Buy Time: 3372, Sell Time: 3374, Buy Price: 104.02, Sell Price: 104.13, Gain/Loss: 54.80, Performance: Win
# Buy Time: 3376, Sell Time: 3382, Buy Price: 104.03, Sell Price: 104.13, Gain/Loss: 43.98, Performance: Win
# Buy Time: 3434, Sell Time: 3435, Buy Price: 104.14, Sell Price: 104.19, Gain/Loss: 23.53, Performance: Win
# Buy Time: 3436, Sell Time: 3438, Buy Price: 104.15, Sell Price: 104.20, Gain/Loss: 22.08, Performance: Win
# Buy Time: 3440, Sell Time: 3442, Buy Price: 104.16, Sell Price: 104.21, Gain/Loss: 26.64, Performance: Win
# Buy Time: 3454, Sell Time: 3474, Buy Price: 104.12, Sell Price: 103.94, Gain/Loss: -87.64, Performance: Loss
# Buy Time: 3475, Sell Time: 3476, Buy Price: 103.91, Sell Price: 103.93, Gain/Loss: 11.55, Performance: Win
# Buy Time: 3477, Sell Time: 3487, Buy Price: 103.88, Sell Price: 103.69, Gain/Loss: -91.21, Performance: Loss
# Buy Time: 3529, Sell Time: 3534, Buy Price: 103.74, Sell Price: 103.77, Gain/Loss: 14.46, Performance: Win
# Buy Time: 3570, Sell Time: 3585, Buy Price: 103.97, Sell Price: 103.66, Gain/Loss: -151.00, Performance: Loss
# Buy Time: 3598, Sell Time: 3599, Buy Price: 103.55, Sell Price: 103.63, Gain/Loss: 41.04, Performance: Win
# Buy Time: 3608, Sell Time: 3614, Buy Price: 103.57, Sell Price: 103.65, Gain/Loss: 39.83, Performance: Win
# Buy Time: 3689, Sell Time: 3696, Buy Price: 103.98, Sell Price: 103.97, Gain/Loss: -3.13, Performance: Loss
# Buy Time: 3697, Sell Time: 3699, Buy Price: 103.95, Sell Price: 104.02, Gain/Loss: 32.71, Performance: Win
# Buy Time: 3776, Sell Time: 3777, Buy Price: 104.38, Sell Price: 104.40, Gain/Loss: 9.82, Performance: Win
# Buy Time: 3778, Sell Time: 3779, Buy Price: 104.38, Sell Price: 104.41, Gain/Loss: 12.45, Performance: Win
# Buy Time: 3787, Sell Time: 3788, Buy Price: 104.39, Sell Price: 104.43, Gain/Loss: 16.52, Performance: Win
# Buy Time: 3789, Sell Time: 3790, Buy Price: 104.39, Sell Price: 104.42, Gain/Loss: 16.05, Performance: Win
# Buy Time: 3822, Sell Time: 3823, Buy Price: 104.45, Sell Price: 104.47, Gain/Loss: 8.62, Performance: Win
# Buy Time: 3829, Sell Time: 3831, Buy Price: 104.43, Sell Price: 104.50, Gain/Loss: 34.23, Performance: Win
# Buy Time: 3844, Sell Time: 3845, Buy Price: 104.42, Sell Price: 104.52, Gain/Loss: 49.08, Performance: Win
# Buy Time: 3861, Sell Time: 3863, Buy Price: 104.43, Sell Price: 104.48, Gain/Loss: 22.74, Performance: Win
# Buy Time: 3864, Sell Time: 3867, Buy Price: 104.45, Sell Price: 104.52, Gain/Loss: 33.27, Performance: Win
# Buy Time: 3885, Sell Time: 3886, Buy Price: 104.47, Sell Price: 104.53, Gain/Loss: 28.48, Performance: Win
# Buy Time: 3904, Sell Time: 3908, Buy Price: 104.51, Sell Price: 104.54, Gain/Loss: 15.31, Performance: Win
# Buy Time: 3918, Sell Time: 3938, Buy Price: 104.48, Sell Price: 104.29, Gain/Loss: -92.84, Performance: Loss
# Buy Time: 3939, Sell Time: 3942, Buy Price: 104.24, Sell Price: 104.28, Gain/Loss: 21.35, Performance: Win
# Buy Time: 3966, Sell Time: 3977, Buy Price: 104.21, Sell Price: 104.25, Gain/Loss: 20.15, Performance: Win
# Buy Time: 3978, Sell Time: 4008, Buy Price: 104.10, Sell Price: 103.64, Gain/Loss: -221.89, Performance: Loss
# Buy Time: 4062, Sell Time: 4066, Buy Price: 103.98, Sell Price: 104.02, Gain/Loss: 15.63, Performance: Win
# Buy Time: 4068, Sell Time: 4071, Buy Price: 104.00, Sell Price: 104.05, Gain/Loss: 21.87, Performance: Win
# Buy Time: 4075, Sell Time: 4076, Buy Price: 103.99, Sell Price: 104.03, Gain/Loss: 16.83, Performance: Win
# Buy Time: 4079, Sell Time: 4084, Buy Price: 103.94, Sell Price: 103.97, Gain/Loss: 14.91, Performance: Win
# Buy Time: 4094, Sell Time: 4095, Buy Price: 103.93, Sell Price: 104.05, Gain/Loss: 55.57, Performance: Win
# Buy Time: 4131, Sell Time: 4132, Buy Price: 104.30, Sell Price: 104.51, Gain/Loss: 104.03, Performance: Win
# Buy Time: 4134, Sell Time: 4139, Buy Price: 104.38, Sell Price: 104.41, Gain/Loss: 13.41, Performance: Win
# Buy Time: 4140, Sell Time: 4141, Buy Price: 104.38, Sell Price: 104.43, Gain/Loss: 25.63, Performance: Win

# %%
print (B_opt, mu_opt, theta_opt, sigma_opt)
# Out:
# -3.2683111674280833e-06 1e-06 94.240639249039 0.0010409586950222967

# %% [markdown]
# ## Live Trading

# %% [markdown]
# ## Trading Strategy Explanation
#
# The trading strategy implemented in the code follows these steps:
#
# ### Setup and Initialization:
# - Connect to the Interactive Brokers (IBKR) API using `ib_insync`.
# - Define the forex contracts for AUDJPY and CADJPY.
# - Set optimized parameters from backtesting for the trading strategy.
#
# ### Fetching Recent Prices:
# - Retrieve recent price data for AUDJPY and CADJPY using the `reqHistoricalData` method from IBKR.
# - Ensure the data is properly fetched and converted into a pandas DataFrame.
#
# ### Calculating Optimal Entry and Exit Prices:
# - **Optimal Entry Price**: Calculate the optimal entry price for trading AUDJPY based on the current prices of AUDJPY and CADJPY. This is done using the formula: `current_audusd_price - B_opt * current_usdchf_price`, where `B_opt` is a parameter from backtesting.
# - **Optimal Exit Price**: Calculate the optimal exit price based on the `theta` parameter from backtesting. This is a placeholder and can be adjusted with more complex logic if needed.
#
# ### Trading Logic:
# - **Determine Trade Action**: Based on the current price of  AUDJPY relative to the optimal entry price:
#   - If the current price is higher than the optimal entry price, place a **BUY** limit order at the optimal entry price.
#   - If the current price is lower than the optimal entry price, place a **SELL** limit order at the optimal entry price.
# - **Place and Monitor Orders**: Place the limit order and monitor its status:
#   - If the order is not filled within 5 minutes, cancel the order.
#   - If the order is filled, monitor the price to determine the exit:
#     - For a **BUY** order, place a **SELL** market order when the price reaches the optimal exit price or after 2 hours.
#     - For a **SELL** order, place a **BUY** market order when the price reaches the optimal exit price or after 2 hours.
#
# ### Main Loop and Trading Hours:
# - The main loop runs continuously during trading hours (7:00 AM to 11:00 PM).
# - Check if it's within trading hours before attempting to place new trades.
# - If outside trading hours, the script waits and checks again after 5 minutes.
#
# ### End-of-Day Processing:
# - At the end of the trading day (after 11:00 PM), close all open positions.
# - Calculate the daily return based on the balance at the start and end of the trading day:
#   - Daily Return = ((End Balance - Start Balance) / Start Balance) * 100
# - Print the daily return and disconnect from the IBKR API.
#
# ### Summary
# This strategy aims to trade AUDJPY based on its relationship with CADJPY. It uses backtested parameters to determine optimal entry and exit points, places limit orders accordingly, and monitors trades to ensure they are executed or canceled as needed. The strategy runs continuously during specified trading hours and calculates the daily return at the end of each trading day.

# %%
import nest_asyncio
from ib_insync import *
from datetime import datetime, time, timedelta
from time import sleep

# Apply nest_asyncio to avoid asyncio loop issues
nest_asyncio.apply()

# Connect to IBKR TWS or Gateway
ib = IB()
connected = ib.connect('127.0.0.1', 7497, clientId=1)

myAccount = 'DU9177866'

# Check connection status
print(f"Connected: {connected}")
# Out:
# Connected: <IB connected to 127.0.0.1:7497 clientId=1>

# %%
# Define the contracts
valuta1_contract = Forex('AUDJPY')
valuta2_contract = Forex('CADJPY')

# Optimized parameters B_opt, mu_opt, theta_opt, sigma_opt comese from backtesting
# Make sure that the backtesting is done before running this script

# %%
########################################## CHAT GPT-4 ##########################################
## Create using Chat GPT-4, explaining the concept and ask for suggestion on how to make the code


# Request tracking
last_requests = []

def can_make_request():
    global last_requests
    now = datetime.now()
    # Remove requests older than 10 minutes
    last_requests = [req_time for req_time in last_requests if now - req_time < timedelta(minutes=10)]
    return len(last_requests) < 60

def get_recent_price(contract, duration='1800 S', bar_size='1 secs'):
    while True:
        if not can_make_request():
            print("Reached request limit. Sleeping for 15 seconds.")
            sleep(15)
            continue

        try:
            bars = ib.reqHistoricalData(
                contract,
                endDateTime='',
                durationStr=duration,
                barSizeSetting=bar_size,
                whatToShow='MIDPOINT',
                useRTH=True,
                formatDate=1
            )
            df = util.df(bars)
            if df is None or df.empty:
                raise ValueError(f"Failed to get historical data for {contract.symbol}")
            
            last_requests.append(datetime.now())
            price = df.iloc[-1]['close']
            print(f"Current {contract.symbol} Price: {price}")
            return price
        except Exception as e:
            if "pacing violation" in str(e).lower():
                print(f"Pacing violation error: {e}. Sleeping for 60 seconds.")
                sleep(60)
            else:
                print(f"An error occurred: {e}")
                sleep(5)

def calculate_optimal_entry(current_valuta1_price, current_valuta2_price):
    return round(current_valuta1_price - B_opt * current_valuta2_price, 3)

def calculate_optimal_exit(theta, mu, sigma):
    return round(theta, 3)  # Placeholder, replace with actual logic if different

def check_account_status():
    account_summary = ib.accountSummary()
    account_values = {av.tag: av.value for av in account_summary if av.account == myAccount}
    
    balance = float(account_values.get('NetLiquidation', 0))
    buying_power = float(account_values.get('BuyingPower', 0))
    selling_power = float(account_values.get('AvailableFunds', 0))
    
    print(f"Balance: {balance}")
    print(f"Buying Power: {buying_power}")
    print(f"Selling Power: {selling_power}")
    
    if balance < 50000 or buying_power < 50000 or selling_power < 50000:  # Example threshold values
        raise ValueError("Insufficient balance, buying power, or selling power to proceed with trading.")
    
    return balance

# %%
########################################## CHAT GPT-4 ##########################################
## Create using Chat GPT-4, explaining the concept and ask for suggestion on how to make the code


def place_and_monitor_order():
    while True:
        current_valuta1_price = get_recent_price(valuta1_contract)
        current_valuta2_price = get_recent_price(valuta2_contract)

        optimal_entry_price = calculate_optimal_entry(current_valuta1_price, current_valuta2_price)
        optimal_exit_price = calculate_optimal_exit(theta_opt, mu_opt, sigma_opt)

        print(f"Current Valuta1 Price: {current_valuta1_price}")
        print(f"Current Valuta2 Price: {current_valuta2_price}")
        print(f"Optimal Entry Price: {optimal_entry_price}")
        print(f"Optimal Exit Price: {optimal_exit_price}")

        trade_quantity = 50000  # Example trade quantity, adjust as needed

        # Determine the initial action based on entry and exit prices
        if optimal_entry_price < optimal_exit_price:
            action = 'BUY'
        else:
            action = 'SELL'

        if (action == 'BUY' and current_valuta1_price <= optimal_entry_price) or (action == 'SELL' and current_valuta1_price >= optimal_entry_price):
            print("Entry conditions not met. Restarting the cycle.")
            sleep(60)  # Sleep for 60 seconds before restarting the cycle
            continue

        limit_price = optimal_entry_price
        print(f"Action: {action}, Limit Price: {limit_price}")

        # Place the limit order for entry
        entry_order = LimitOrder(action, trade_quantity, limit_price, tif='DAY')
        entry_trade = ib.placeOrder(valuta1_contract, entry_order)

        print(f"Placed {action} limit order at {limit_price}")
        print(entry_trade)

        filled = False
        start_time = datetime.now()
        while (datetime.now() - start_time) < timedelta(minutes=5):
            if entry_trade.orderStatus.status == 'Filled':
                filled = True
                break
            ib.sleep(5)

        if not filled:
            ib.cancelOrder(entry_trade.order)
            print(f"Cancelled {action} limit order at {limit_price}")
            continue
        else:
            print(f"Order filled: {action} at {limit_price}")
            print(entry_trade)

            # Place a take profit order
            opposite_action = 'SELL' if action == 'BUY' else 'BUY'
            take_profit_order = LimitOrder(opposite_action, trade_quantity, optimal_exit_price, tif='DAY')
            take_profit_trade = ib.placeOrder(valuta1_contract, take_profit_order)
            print(f"Placed {opposite_action} take profit order at {optimal_exit_price}")
            print(take_profit_trade)

            entry_time = datetime.now()
            while (datetime.now() - entry_time) < timedelta(hours=2):
                current_valuta1_price = get_recent_price(valuta1_contract)
                print(f"Current Valuta1 Price: {current_valuta1_price}")  # Debugging
                if (action == 'BUY' and current_valuta1_price >= optimal_exit_price) or \
                   (action == 'SELL' and current_valuta1_price <= optimal_exit_price):
                    close_order = MarketOrder(opposite_action, trade_quantity)
                    close_trade = ib.placeOrder(valuta1_contract, close_order)
                    while not close_trade.isDone():
                        ib.waitOnUpdate()
                    print(f"Closed position with {opposite_action} order at {current_valuta1_price}")
                    print(close_trade)
                    break
                ib.sleep(60)  # Sleep for 60 seconds before checking the price again

            # If the position is still open after 2 hours, close it
            if (datetime.now() - entry_time) >= timedelta(hours=2):
                # Cancel the take profit order
                ib.cancelOrder(take_profit_order)
                print(f"Cancelled take profit order at {optimal_exit_price}")

                # Place market order to close the position
                close_order = MarketOrder(opposite_action, trade_quantity)
                close_trade = ib.placeOrder(valuta1_contract, close_order)
                while not close_trade.isDone():
                    ib.waitOnUpdate()
                print(f"Closed position after 2 hours with {opposite_action} market order at {current_valuta1_price}")
                print(close_trade)

def within_trading_hours():
    now = datetime.now().time()
    return time(7, 0) <= now <= time(23, 0)

# %%
# Main loop
start_balance = check_account_status()  # Initial balance at the start of the day
print(f"Start Balance: {start_balance}")

while True:
    if within_trading_hours():
        try:
            place_and_monitor_order()
        except Exception as e:
            print(f"An error occurred: {e}")
            ib.sleep(5)  # Wait before retrying
    else:
        print("Outside trading hours. Waiting...")
        sleep(300)  # Wait 5 minutes before checking again

        if datetime.now().time() > time(23, 0):
            positions = ib.positions(account=myAccount)
            for position in positions:
                contract = position.contract
                position_size = position.position
                if position_size > 0:
                    close_action = 'SELL'
                else:
                    close_action = 'BUY'
                close_order = MarketOrder(close_action, abs(position_size))
                ib.placeOrder(contract, close_order)
                print(f"Closed {close_action} position of {position_size} for {contract}")

            break
# Out:
# Balance: 1004168.64
# Buying Power: 3992711.53
# Selling Power: 998177.88
# Start Balance: 1004168.64
# Current AUD Price: 105.8045
# Current CAD Price: 116.3415
# Current Valuta1 Price: 105.8045
# Current Valuta2 Price: 116.3415
# Optimal Entry Price: 105.805
# Optimal Exit Price: 94.241
# Action: SELL, Limit Price: 105.805
# Placed SELL limit order at 105.805
# Trade(contract=Forex('AUDJPY', exchange='IDEALPRO'), order=LimitOrder(orderId=2230, clientId=1, action='SELL', totalQuantity=50000, lmtPrice=105.805, tif='DAY'), orderStatus=OrderStatus(orderId=2230, status='PendingSubmit', filled=0.0, remaining=0.0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 6, 21, 15, 42, 30, 950951, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0)], advancedError='')
# Order filled: SELL at 105.805
# Trade(contract=Forex('AUDJPY', exchange='IDEALPRO'), order=LimitOrder(orderId=2230, clientId=1, permId=1193614556, action='SELL', totalQuantity=50000.0, lmtPrice=105.805, auxPrice=0.0, tif='DAY'), orderStatus=OrderStatus(orderId=2230, status='Filled', filled=50000.0, remaining=0.0, avgFillPrice=105.808, permId=1193614556, parentId=0, lastFillPrice=105.808, clientId=1, whyHeld='', mktCapPrice=0.0), fills=[Fill(contract=Forex('AUDJPY', conId=15016133, exchange='IDEALPRO', localSymbol='AUD.JPY', tradingClass='AUD.JPY'), execution=Execution(execId='0000e215.6674be8c.01.01', time=datetime.datetime(2024, 6, 21, 15, 42, 31, tzinfo=datetime.timezone.utc), acctNumber='DU9177866', exchange='IDEALPRO', side='SLD', shares=50000.0, price=105.808, permId=1193614556, clientId=1, orderId=2230, liquidation=0, cumQty=50000.0, avgPrice=105.808, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2), commissionReport=CommissionReport(execId='0000e215.6674be8c.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0), time=datetime.datetime(2024, 6, 21, 15, 42, 31, 324407, tzinfo=datetime.timezone.utc))], log=[TradeLogEntry(time=datetime.datetime(2024, 6, 21, 15, 42, 30, 950951, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 6, 21, 15, 42, 31, 320053, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 6, 21, 15, 42, 31, 324407, tzinfo=datetime.timezone.utc), status='Submitted', message='Fill 50000.0@105.808', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 6, 21, 15, 42, 31, 324727, tzinfo=datetime.timezone.utc), status='Filled', message='', errorCode=0)], advancedError='')
# Placed BUY take profit order at 94.241
# Trade(contract=Forex('AUDJPY', exchange='IDEALPRO'), order=LimitOrder(orderId=2231, clientId=1, action='BUY', totalQuantity=50000, lmtPrice=94.241, tif='DAY'), orderStatus=OrderStatus(orderId=2231, status='PendingSubmit', filled=0.0, remaining=0.0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 6, 21, 15, 42, 35, 955062, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0)], advancedError='')
# Current AUD Price: 105.807
# Current Valuta1 Price: 105.807
# Current AUD Price: 105.7925
# Current Valuta1 Price: 105.7925
# Current AUD Price: 105.795
# Current Valuta1 Price: 105.795
# Current AUD Price: 105.815
# Current Valuta1 Price: 105.815
# Current AUD Price: 105.815
# Current Valuta1 Price: 105.815
# Current AUD Price: 105.7995
# Current Valuta1 Price: 105.7995
# Current AUD Price: 105.7965
# Current Valuta1 Price: 105.7965
# Current AUD Price: 105.802
# Current Valuta1 Price: 105.802
# Current AUD Price: 105.81
# Current Valuta1 Price: 105.81
# Current AUD Price: 105.8335
# Current Valuta1 Price: 105.8335
# Current AUD Price: 105.841
# Current Valuta1 Price: 105.841

# %%
# Calculate the daily return after the trading day ends and all positions are closed
end_balance = check_account_status()  # Balance at the end of the day
print(f"End Balance: {end_balance}")

# Calculate the daily return
daily_return = (end_balance - start_balance) / start_balance * 100
print(f"Daily Return: {daily_return:.2f}%")
# Out:
# Balance: 1004168.64
# Buying Power: 3992711.53
# Selling Power: 998177.88
# End Balance: 1004168.64
# Daily Return: 0.00%

# %%
ib.disconnect()
