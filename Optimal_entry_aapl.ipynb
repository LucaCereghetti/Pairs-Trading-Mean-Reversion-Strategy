# %%
import nest_asyncio
import asyncio
from ib_insync import *
import pandas as pd
import numpy as np
from scipy.optimize import minimize
import time

nest_asyncio.apply()

# Connect to IBKR TWS or Gateway
ib = IB()
ib.connect('127.0.0.1', 7497, clientId=2)

def Now():
    """Return the current time as a string."""
    return time.strftime('%Y-%m-%d %H:%M:%S')

def fetch_historical_data(contract, duration='5 D', bar_size='1 min'):
    """Fetch historical data for a given contract."""
    bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr=duration,
        barSizeSetting=bar_size,
        whatToShow='MIDPOINT',
        useRTH=True
    )
    if bars:
        df = util.df(bars)
        print("%s Historical data fetched: %s" % (Now(), df.head()))
        return df
    else:
        print("%s No historical data fetched" % Now())
        return None

def estimate_ou_parameters(df):
    """Estimate parameters of the Ornstein-Uhlenbeck process."""
    dt = 1 / (24 * 60)  # 1-minute data
    x = df['close'].values
    n = len(x)

    # Estimate parameters
    def neg_log_likelihood(params):
        mu, theta, sigma = params
        if sigma <= 0 or mu <= 0:
            return np.inf
        likelihoods = -np.log(sigma) - 0.5 * (((x[1:] - x[:-1] * np.exp(-mu*dt) - theta * (1 - np.exp(-mu*dt))) / sigma) ** 2)
        return -np.sum(likelihoods)

    initial_params = [0.1, np.mean(x), np.std(x)]
    bounds = ((1e-5, None), (None, None), (1e-5, None))  # Avoid zero or negative values
    result = minimize(neg_log_likelihood, initial_params, bounds=bounds)
    
    if not result.success:
        raise ValueError("Parameter estimation failed")

    mu, theta, sigma = result.x
    print("%s Estimated parameters - mu: %s, theta: %s, sigma: %s" % (Now(), mu, theta, sigma))
    return mu, theta, sigma

def calculate_entry_exit_levels(mu, theta, sigma, r, c, stop_loss):
    """Calculate optimal entry and exit levels based on OU parameters and constraints."""
    def value_function_exit(x):
        return (x - c) * np.exp(-r * (1 / mu) * np.log(x / theta))

    def value_function_entry(x):
        return value_function_exit(x) - x - c

    b_star = minimize(lambda x: -value_function_exit(x), x0=theta, bounds=((stop_loss, None),)).x[0]
    a_star = minimize(lambda x: -value_function_entry(x), x0=theta, bounds=((stop_loss, b_star),)).x[0]
    print("%s Calculated levels - a_star: %s, b_star: %s" % (Now(), a_star, b_star))
    return a_star, b_star

def place_market_order(contract, action, quantity):
    """Place a market order for a specified quantity."""
    order = MarketOrder(action, quantity)
    trade = ib.placeOrder(contract, order)
    print(f"{Now()} Placing {action} market order for {quantity} units")

    while not trade.isDone():
        ib.waitOnUpdate()

    price = trade.fills[0].execution.avgPrice if trade.fills else None
    if price:
        print(f"{Now()} Placed {action} market order for {quantity} units at price {price}")
    else:
        print(f"{Now()} {action} market order for {quantity} units was not filled")
    return price

def get_account_balance():
    """Retrieve account balance."""
    account_values = ib.accountValues()
    net_liquidation = next((x for x in account_values if x.tag == 'NetLiquidation'), None)
    if net_liquidation:
        return float(net_liquidation.value)
    return 0.0

async def main():
    # Parameters
    check_window = "5 D"
    bar_size = "1 min"
    contract = Stock('AAPL', 'SMART', 'USD')
    r = 0.01  # Example discount rate
    c = 0.01  # Example transaction cost
    stop_loss_percent = 0.01  # Example stop-loss level as a percentage
    trade_amount = 200  # Number of AAPL shares to trade
    hold_seconds = 300  # Hold for 5 minutes (300 seconds)
    wait = 60  # Check every 60 seconds

    # Fetch historical data and estimate parameters
    df = fetch_historical_data(contract, duration=check_window, bar_size=bar_size)
    if df is not None:
        mu, theta, sigma = estimate_ou_parameters(df)
        a_star, b_star = calculate_entry_exit_levels(mu, theta, sigma, r, c, stop_loss_percent)
        initial_balance = get_account_balance()  # Get the initial account balance
        print("%s Initial account balance: $%s" % (Now(), initial_balance))
    else:
        print("%s Historical data could not be fetched. Exiting." % Now())
        return

    while True:
        # Data
        bars = await ib.reqHistoricalDataAsync(contract, endDateTime='', durationStr=check_window, barSizeSetting=bar_size, whatToShow='MIDPOINT', useRTH=True)
        df = util.df(bars)
        print("%s Data downloaded" % Now())

        # Check condition for mean-reversion strategy
        p_movement = round(df["close"].iloc[-1] / df["open"].iloc[0] - 1, 6)
        condition = p_movement > 0.0001 / 100  # 0.01%

        if condition:
            print(f"{Now()} Condition met ({p_movement}), open trade with market order")
            ib.qualifyContracts(contract)
            price_sell = place_market_order(contract, "SELL", trade_amount)
            if price_sell:
                print("%s Trade opened: Sold at %s" % (Now(), price_sell))

                # Hold the trade
                print("%s Holding the trade" % Now())
                await asyncio.sleep(hold_seconds)

                # Close the trade
                print(f"{Now()} Closing the trade with market order")
                price_buy_back = place_market_order(contract, "BUY", trade_amount)
                if price_buy_back:
                    print("%s Trade closed: Bought back at %s" % (Now(), price_buy_back))

                    profit = "%s %%" % round(100 * (price_sell / price_buy_back - 1), 6)
                    print("%s Gross profit from trade: %s" % (Now(), profit))
                else:
                    print("%s Failed to buy back the shares" % Now())
            else:
                print("%s Failed to sell the shares" % Now())
        else:
            print("%s Condition not met (%s), do not open any trade" % (Now(), p_movement))

        # Wait for the next iteration
        print("%s ........ wait for %s secs ........." % (Now(), wait))
        await asyncio.sleep(wait)

# Run the main function using asyncio
asyncio.run(main())
# Out:
# 2024-06-07 18:03:13 Historical data fetched:                        date    open    high     low   close  volume  average  \
# 0 2024-06-03 09:30:00-04:00  192.99  193.34  192.77  193.33    -1.0     -1.0
# 1 2024-06-03 09:31:00-04:00  193.33  193.39  192.58  192.78    -1.0     -1.0
# 2 2024-06-03 09:32:00-04:00  192.78  192.91  192.52  192.78    -1.0     -1.0
# 3 2024-06-03 09:33:00-04:00  192.78  192.98  192.65  192.80    -1.0     -1.0
# 4 2024-06-03 09:34:00-04:00  192.80  193.24  192.75  193.14    -1.0     -1.0
#
#    barCount
# 0        -1
# 1        -1
# 2        -1
# 3        -1
# 4        -1
# 2024-06-07 18:03:13 Estimated parameters - mu: 8.804150692144246, theta: 195.14673748207107, sigma: 0.10279138726017338
# 2024-06-07 18:03:13 Calculated levels - a_star: 71.7239754716066, b_star: 6.056808599844238e+37
# 2024-06-07 18:03:13 Initial account balance: $1005580.8
# 2024-06-07 18:03:13 Data downloaded
# 2024-06-07 18:03:13 Condition met (0.014768), open trade with market order
# 2024-06-07 18:03:13 Placing SELL market order for 200 units
# 2024-06-07 18:03:14 Placed SELL market order for 200 units at price 195.83
# 2024-06-07 18:03:14 Trade opened: Sold at 195.83
# 2024-06-07 18:03:14 Holding the trade
# 2024-06-07 18:08:14 Closing the trade with market order
# 2024-06-07 18:08:14 Placing BUY market order for 200 units
# 2024-06-07 18:08:14 Placed BUY market order for 200 units at price 196.06
# 2024-06-07 18:08:14 Trade closed: Bought back at 196.06
# 2024-06-07 18:08:14 Gross profit from trade: -0.117311 %
# 2024-06-07 18:08:14 ........ wait for 60 secs .........
# 2024-06-07 18:09:15 Data downloaded
# 2024-06-07 18:09:15 Condition met (0.01627), open trade with market order
# 2024-06-07 18:09:15 Placing SELL market order for 200 units
# 2024-06-07 18:09:15 Placed SELL market order for 200 units at price 196.13
# 2024-06-07 18:09:15 Trade opened: Sold at 196.13
# 2024-06-07 18:09:15 Holding the trade
# 2024-06-07 18:14:15 Closing the trade with market order
# 2024-06-07 18:14:15 Placing BUY market order for 200 units
# 2024-06-07 18:14:15 Placed BUY market order for 200 units at price 195.98
# 2024-06-07 18:14:15 Trade closed: Bought back at 195.98
# 2024-06-07 18:14:15 Gross profit from trade: 0.076538 %
# 2024-06-07 18:14:15 ........ wait for 60 secs .........
# 2024-06-07 18:15:16 Data downloaded
# 2024-06-07 18:15:16 Condition met (0.014819), open trade with market order
# 2024-06-07 18:15:16 Placing SELL market order for 200 units
# 2024-06-07 18:15:16 Placed SELL market order for 200 units at price 195.85
# 2024-06-07 18:15:16 Trade opened: Sold at 195.85
# 2024-06-07 18:15:16 Holding the trade
# 2024-06-07 18:20:16 Closing the trade with market order
# 2024-06-07 18:20:16 Placing BUY market order for 200 units
# 2024-06-07 18:20:17 Placed BUY market order for 200 units at price 195.66
# 2024-06-07 18:20:17 Trade closed: Bought back at 195.66
# 2024-06-07 18:20:17 Gross profit from trade: 0.097107 %
# 2024-06-07 18:20:17 ........ wait for 60 secs .........
# 2024-06-07 18:21:17 Data downloaded
# 2024-06-07 18:21:17 Condition met (0.013835), open trade with market order
# 2024-06-07 18:21:17 Placing SELL market order for 200 units
# 2024-06-07 18:21:20 Placed SELL market order for 200 units at price 195.65
# 2024-06-07 18:21:20 Trade opened: Sold at 195.65
# 2024-06-07 18:21:20 Holding the trade
# 2024-06-07 18:26:20 Closing the trade with market order
# 2024-06-07 18:26:20 Placing BUY market order for 200 units
# 2024-06-07 18:26:20 Placed BUY market order for 200 units at price 195.9
# 2024-06-07 18:26:20 Trade closed: Bought back at 195.9
# 2024-06-07 18:26:20 Gross profit from trade: -0.127616 %
# 2024-06-07 18:26:20 ........ wait for 60 secs .........
# 2024-06-07 18:27:21 Data downloaded
# 2024-06-07 18:27:21 Condition met (0.014716), open trade with market order
# 2024-06-07 18:27:21 Placing SELL market order for 200 units
# 2024-06-07 18:27:21 Placed SELL market order for 200 units at price 195.82
# 2024-06-07 18:27:21 Trade opened: Sold at 195.82
# 2024-06-07 18:27:21 Holding the trade
# 2024-06-07 18:32:21 Closing the trade with market order
# 2024-06-07 18:32:21 Placing BUY market order for 200 units
# 2024-06-07 18:32:21 Placed BUY market order for 200 units at price 196.08
# 2024-06-07 18:32:21 Trade closed: Bought back at 196.08
# 2024-06-07 18:32:21 Gross profit from trade: -0.132599 %
# 2024-06-07 18:32:21 ........ wait for 60 secs .........
# 2024-06-07 18:33:22 Data downloaded
# 2024-06-07 18:33:22 Condition met (0.01627), open trade with market order
# 2024-06-07 18:33:22 Placing SELL market order for 200 units
# 2024-06-07 18:33:23 Placed SELL market order for 200 units at price 196.12
# 2024-06-07 18:33:23 Trade opened: Sold at 196.12
# 2024-06-07 18:33:23 Holding the trade
# 2024-06-07 18:38:23 Closing the trade with market order
# 2024-06-07 18:38:23 Placing BUY market order for 200 units
# 2024-06-07 18:38:23 Placed BUY market order for 200 units at price 195.97
# 2024-06-07 18:38:23 Trade closed: Bought back at 195.97
# 2024-06-07 18:38:23 Gross profit from trade: 0.076542 %
# 2024-06-07 18:38:23 ........ wait for 60 secs .........
# 2024-06-07 18:39:24 Data downloaded
# 2024-06-07 18:39:24 Condition met (0.015286), open trade with market order
# 2024-06-07 18:39:24 Placing SELL market order for 200 units
# 2024-06-07 18:39:24 Placed SELL market order for 200 units at price 195.94
# 2024-06-07 18:39:24 Trade opened: Sold at 195.94
# 2024-06-07 18:39:24 Holding the trade
# 2024-06-07 18:44:24 Closing the trade with market order
# 2024-06-07 18:44:24 Placing BUY market order for 200 units
# 2024-06-07 18:44:24 Placed BUY market order for 200 units at price 195.84
# 2024-06-07 18:44:24 Trade closed: Bought back at 195.84
# 2024-06-07 18:44:24 Gross profit from trade: 0.051062 %
# 2024-06-07 18:44:24 ........ wait for 60 secs .........
# 2024-06-07 18:45:25 Data downloaded
# 2024-06-07 18:45:25 Condition met (0.014923), open trade with market order
# 2024-06-07 18:45:25 Placing SELL market order for 200 units
# 2024-06-07 18:45:26 Placed SELL market order for 200 units at price 195.87
# 2024-06-07 18:45:26 Trade opened: Sold at 195.87
# 2024-06-07 18:45:26 Holding the trade
# 2024-06-07 18:50:26 Closing the trade with market order
# 2024-06-07 18:50:26 Placing BUY market order for 200 units
# 2024-06-07 18:50:26 Placed BUY market order for 200 units at price 195.93
# 2024-06-07 18:50:26 Trade closed: Bought back at 195.93
# 2024-06-07 18:50:26 Gross profit from trade: -0.030623 %
# 2024-06-07 18:50:26 ........ wait for 60 secs .........
# 2024-06-07 18:51:27 Data downloaded
# 2024-06-07 18:51:27 Condition met (0.015182), open trade with market order
# 2024-06-07 18:51:27 Placing SELL market order for 200 units
# 2024-06-07 18:51:27 Placed SELL market order for 200 units at price 195.91
# 2024-06-07 18:51:27 Trade opened: Sold at 195.91
# 2024-06-07 18:51:27 Holding the trade
# 2024-06-07 18:56:27 Closing the trade with market order
# 2024-06-07 18:56:27 Placing BUY market order for 200 units
# 2024-06-07 18:56:28 Placed BUY market order for 200 units at price 196.3
# 2024-06-07 18:56:28 Trade closed: Bought back at 196.3
# 2024-06-07 18:56:28 Gross profit from trade: -0.198675 %
# 2024-06-07 18:56:28 ........ wait for 60 secs .........
# 2024-06-07 18:57:29 Data downloaded
# 2024-06-07 18:57:29 Condition met (0.017669), open trade with market order
# 2024-06-07 18:57:29 Placing SELL market order for 200 units
# 2024-06-07 18:57:29 Placed SELL market order for 200 units at price 196.39
# 2024-06-07 18:57:29 Trade opened: Sold at 196.39
# 2024-06-07 18:57:29 Holding the trade
# 2024-06-07 19:02:29 Closing the trade with market order
# 2024-06-07 19:02:29 Placing BUY market order for 200 units
# 2024-06-07 19:02:29 Placed BUY market order for 200 units at price 196.23
# 2024-06-07 19:02:29 Trade closed: Bought back at 196.23
# 2024-06-07 19:02:29 Gross profit from trade: 0.081537 %
# 2024-06-07 19:02:29 ........ wait for 60 secs .........
# 2024-06-07 19:03:30 Data downloaded
# 2024-06-07 19:03:30 Condition met (0.017203), open trade with market order
# 2024-06-07 19:03:30 Placing SELL market order for 200 units
# 2024-06-07 19:03:30 Placed SELL market order for 200 units at price 196.31
# 2024-06-07 19:03:30 Trade opened: Sold at 196.31
# 2024-06-07 19:03:30 Holding the trade
# 2024-06-07 19:08:30 Closing the trade with market order
# 2024-06-07 19:08:30 Placing BUY market order for 200 units
# 2024-06-07 19:08:31 Placed BUY market order for 200 units at price 196.17
# 2024-06-07 19:08:31 Trade closed: Bought back at 196.17
# 2024-06-07 19:08:31 Gross profit from trade: 0.071367 %
# 2024-06-07 19:08:31 ........ wait for 60 secs .........
# 2024-06-07 19:09:31 Data downloaded
# 2024-06-07 19:09:31 Condition met (0.016426), open trade with market order
# 2024-06-07 19:09:31 Placing SELL market order for 200 units
# 2024-06-07 19:09:32 Placed SELL market order for 200 units at price 196.16
# 2024-06-07 19:09:32 Trade opened: Sold at 196.16
# 2024-06-07 19:09:32 Holding the trade
# 2024-06-07 19:14:32 Closing the trade with market order
# 2024-06-07 19:14:32 Placing BUY market order for 200 units
# 2024-06-07 19:14:32 Placed BUY market order for 200 units at price 196.31
# 2024-06-07 19:14:32 Trade closed: Bought back at 196.31
# 2024-06-07 19:14:32 Gross profit from trade: -0.07641 %
# 2024-06-07 19:14:32 ........ wait for 60 secs .........
# 2024-06-07 19:15:33 Data downloaded
# 2024-06-07 19:15:33 Condition met (0.017048), open trade with market order
# 2024-06-07 19:15:33 Placing SELL market order for 200 units
# 2024-06-07 19:15:33 Placed SELL market order for 200 units at price 196.28
# 2024-06-07 19:15:33 Trade opened: Sold at 196.28
# 2024-06-07 19:15:33 Holding the trade
# 2024-06-07 19:20:33 Closing the trade with market order
# 2024-06-07 19:20:33 Placing BUY market order for 200 units
# 2024-06-07 19:20:33 Placed BUY market order for 200 units at price 196.25
# 2024-06-07 19:20:33 Trade closed: Bought back at 196.25
# 2024-06-07 19:20:33 Gross profit from trade: 0.015287 %
# 2024-06-07 19:20:33 ........ wait for 60 secs .........
# 2024-06-07 19:21:34 Data downloaded
# 2024-06-07 19:21:34 Condition met (0.017151), open trade with market order
# 2024-06-07 19:21:34 Placing SELL market order for 200 units
# 2024-06-07 19:21:35 Placed SELL market order for 200 units at price 196.31
# 2024-06-07 19:21:35 Trade opened: Sold at 196.31
# 2024-06-07 19:21:35 Holding the trade
# 2024-06-07 19:26:35 Closing the trade with market order
# 2024-06-07 19:26:35 Placing BUY market order for 200 units
# 2024-06-07 19:26:35 Placed BUY market order for 200 units at price 196.41
# 2024-06-07 19:26:35 Trade closed: Bought back at 196.41
# 2024-06-07 19:26:35 Gross profit from trade: -0.050914 %
# 2024-06-07 19:26:35 ........ wait for 60 secs .........
# 2024-06-07 19:27:36 Data downloaded
# 2024-06-07 19:27:36 Condition met (0.017462), open trade with market order
# 2024-06-07 19:27:36 Placing SELL market order for 200 units
# 2024-06-07 19:27:37 Placed SELL market order for 200 units at price 196.35
# 2024-06-07 19:27:37 Trade opened: Sold at 196.35
# 2024-06-07 19:27:37 Holding the trade
# 2024-06-07 19:32:37 Closing the trade with market order
# 2024-06-07 19:32:37 Placing BUY market order for 200 units
# 2024-06-07 19:32:37 Placed BUY market order for 200 units at price 196.39
# 2024-06-07 19:32:37 Trade closed: Bought back at 196.39
# 2024-06-07 19:32:37 Gross profit from trade: -0.020368 %
# 2024-06-07 19:32:37 ........ wait for 60 secs .........
# 2024-06-07 19:33:37 Data downloaded
# 2024-06-07 19:33:37 Condition met (0.017617), open trade with market order
# 2024-06-07 19:33:37 Placing SELL market order for 200 units
# 2024-06-07 19:33:39 Placed SELL market order for 200 units at price 196.39
# 2024-06-07 19:33:39 Trade opened: Sold at 196.39
# 2024-06-07 19:33:39 Holding the trade
# 2024-06-07 19:38:39 Closing the trade with market order
# 2024-06-07 19:38:39 Placing BUY market order for 200 units
# 2024-06-07 19:38:39 Placed BUY market order for 200 units at price 196.3
# 2024-06-07 19:38:39 Trade closed: Bought back at 196.3
# 2024-06-07 19:38:39 Gross profit from trade: 0.045848 %
# 2024-06-07 19:38:39 ........ wait for 60 secs .........
# 2024-06-07 19:39:40 Data downloaded
# 2024-06-07 19:39:40 Condition met (0.017358), open trade with market order
# 2024-06-07 19:39:40 Placing SELL market order for 200 units
# 2024-06-07 19:39:42 Placed SELL market order for 200 units at price 196.34
# 2024-06-07 19:39:42 Trade opened: Sold at 196.34
# 2024-06-07 19:39:42 Holding the trade
# 2024-06-07 19:44:42 Closing the trade with market order
# 2024-06-07 19:44:42 Placing BUY market order for 200 units
# 2024-06-07 19:44:42 Placed BUY market order for 200 units at price 196.28
# 2024-06-07 19:44:42 Trade closed: Bought back at 196.28
# 2024-06-07 19:44:42 Gross profit from trade: 0.030569 %
# 2024-06-07 19:44:42 ........ wait for 60 secs .........
# 2024-06-07 19:45:43 Data downloaded
# 2024-06-07 19:45:43 Condition met (0.016788), open trade with market order
# 2024-06-07 19:45:43 Placing SELL market order for 200 units
# 2024-06-07 19:45:44 Placed SELL market order for 200 units at price 196.22
# 2024-06-07 19:45:44 Trade opened: Sold at 196.22
# 2024-06-07 19:45:44 Holding the trade
# 2024-06-07 19:50:44 Closing the trade with market order
# 2024-06-07 19:50:44 Placing BUY market order for 200 units
# 2024-06-07 19:50:44 Placed BUY market order for 200 units at price 196.27
# 2024-06-07 19:50:44 Trade closed: Bought back at 196.27
# 2024-06-07 19:50:44 Gross profit from trade: -0.025475 %
# 2024-06-07 19:50:44 ........ wait for 60 secs .........
# 2024-06-07 19:51:45 Data downloaded
# 2024-06-07 19:51:45 Condition met (0.017203), open trade with market order
# 2024-06-07 19:51:45 Placing SELL market order for 200 units
# 2024-06-07 19:51:46 Placed SELL market order for 200 units at price 196.3
# 2024-06-07 19:51:46 Trade opened: Sold at 196.3
# 2024-06-07 19:51:46 Holding the trade
# 2024-06-07 19:56:46 Closing the trade with market order
# 2024-06-07 19:56:46 Placing BUY market order for 200 units
# 2024-06-07 19:56:46 Placed BUY market order for 200 units at price 196.43
# 2024-06-07 19:56:46 Trade closed: Bought back at 196.43
# 2024-06-07 19:56:46 Gross profit from trade: -0.066181 %
# 2024-06-07 19:56:46 ........ wait for 60 secs .........
# 2024-06-07 19:57:47 Data downloaded
# 2024-06-07 19:57:47 Condition met (0.018032), open trade with market order
# 2024-06-07 19:57:47 Placing SELL market order for 200 units
# 2024-06-07 19:57:48 Placed SELL market order for 200 units at price 196.47
# 2024-06-07 19:57:48 Trade opened: Sold at 196.47
# 2024-06-07 19:57:48 Holding the trade
# 2024-06-07 20:02:48 Closing the trade with market order
# 2024-06-07 20:02:48 Placing BUY market order for 200 units
# 2024-06-07 20:02:49 Placed BUY market order for 200 units at price 196.35
# 2024-06-07 20:02:49 Trade closed: Bought back at 196.35
# 2024-06-07 20:02:49 Gross profit from trade: 0.061115 %
# 2024-06-07 20:02:49 ........ wait for 60 secs .........
# 2024-06-07 20:03:49 Data downloaded
# 2024-06-07 20:03:49 Condition met (0.017514), open trade with market order
# 2024-06-07 20:03:49 Placing SELL market order for 200 units
# 2024-06-07 20:03:49 Placed SELL market order for 200 units at price 196.36
# 2024-06-07 20:03:49 Trade opened: Sold at 196.36
# 2024-06-07 20:03:49 Holding the trade
# 2024-06-07 20:08:49 Closing the trade with market order
# 2024-06-07 20:08:50 Placing BUY market order for 200 units
# 2024-06-07 20:08:50 Placed BUY market order for 200 units at price 195.96
# 2024-06-07 20:08:50 Trade closed: Bought back at 195.96
# 2024-06-07 20:08:50 Gross profit from trade: 0.204123 %
# 2024-06-07 20:08:50 ........ wait for 60 secs .........
# 2024-06-07 20:09:50 Data downloaded
# 2024-06-07 20:09:50 Condition met (0.015648), open trade with market order
# 2024-06-07 20:09:50 Placing SELL market order for 200 units
# 2024-06-07 20:09:51 Placed SELL market order for 200 units at price 195.98
# 2024-06-07 20:09:51 Trade opened: Sold at 195.98
# 2024-06-07 20:09:51 Holding the trade
# 2024-06-07 20:14:51 Closing the trade with market order
# 2024-06-07 20:14:51 Placing BUY market order for 200 units
# 2024-06-07 20:14:51 Placed BUY market order for 200 units at price 195.88
# 2024-06-07 20:14:51 Trade closed: Bought back at 195.88
# 2024-06-07 20:14:51 Gross profit from trade: 0.051052 %
# 2024-06-07 20:14:51 ........ wait for 60 secs .........
# 2024-06-07 20:15:52 Data downloaded
# 2024-06-07 20:15:52 Condition met (0.014871), open trade with market order
# 2024-06-07 20:15:52 Placing SELL market order for 200 units
# 2024-06-07 20:15:52 Placed SELL market order for 200 units at price 195.81
# 2024-06-07 20:15:52 Trade opened: Sold at 195.81
# 2024-06-07 20:15:52 Holding the trade
# 2024-06-07 20:20:52 Closing the trade with market order
# 2024-06-07 20:20:52 Placing BUY market order for 200 units
# 2024-06-07 20:20:52 Placed BUY market order for 200 units at price 196.02
# 2024-06-07 20:20:52 Trade closed: Bought back at 196.02
# 2024-06-07 20:20:52 Gross profit from trade: -0.107132 %
# 2024-06-07 20:20:52 ........ wait for 60 secs .........
# 2024-06-07 20:21:53 Data downloaded
# 2024-06-07 20:21:53 Condition met (0.015441), open trade with market order
# 2024-06-07 20:21:53 Placing SELL market order for 200 units
# 2024-06-07 20:21:54 Placed SELL market order for 200 units at price 195.97
# 2024-06-07 20:21:54 Trade opened: Sold at 195.97
# 2024-06-07 20:21:54 Holding the trade
# 2024-06-07 20:26:54 Closing the trade with market order
# 2024-06-07 20:26:54 Placing BUY market order for 200 units
# 2024-06-07 20:26:55 Placed BUY market order for 200 units at price 195.95
# 2024-06-07 20:26:55 Trade closed: Bought back at 195.95
# 2024-06-07 20:26:55 Gross profit from trade: 0.010207 %
# 2024-06-07 20:26:55 ........ wait for 60 secs .........
# 2024-06-07 20:27:55 Data downloaded
# 2024-06-07 20:27:55 Condition met (0.015545), open trade with market order
# 2024-06-07 20:27:55 Placing SELL market order for 200 units
# 2024-06-07 20:27:56 Placed SELL market order for 200 units at price 195.98
# 2024-06-07 20:27:56 Trade opened: Sold at 195.98
# 2024-06-07 20:27:56 Holding the trade
# 2024-06-07 20:32:56 Closing the trade with market order
# 2024-06-07 20:32:56 Placing BUY market order for 200 units
# 2024-06-07 20:32:57 Placed BUY market order for 200 units at price 195.62
# 2024-06-07 20:32:57 Trade closed: Bought back at 195.62
# 2024-06-07 20:32:57 Gross profit from trade: 0.18403 %
# 2024-06-07 20:32:57 ........ wait for 60 secs .........
# 2024-06-07 20:33:58 Data downloaded
# 2024-06-07 20:33:58 Condition met (0.014146), open trade with market order
# 2024-06-07 20:33:58 Placing SELL market order for 200 units
# 2024-06-07 20:33:58 Placed SELL market order for 200 units at price 195.7
# 2024-06-07 20:33:58 Trade opened: Sold at 195.7
# 2024-06-07 20:33:58 Holding the trade
# 2024-06-07 20:38:58 Closing the trade with market order
# 2024-06-07 20:38:58 Placing BUY market order for 200 units
# 2024-06-07 20:38:58 Placed BUY market order for 200 units at price 195.69
# 2024-06-07 20:38:58 Trade closed: Bought back at 195.69
# 2024-06-07 20:38:58 Gross profit from trade: 0.00511 %
# 2024-06-07 20:38:58 ........ wait for 60 secs .........
# 2024-06-07 20:39:59 Data downloaded
# 2024-06-07 20:39:59 Condition met (0.014042), open trade with market order
# 2024-06-07 20:39:59 Placing SELL market order for 200 units
# 2024-06-07 20:40:00 Placed SELL market order for 200 units at price 195.69
# 2024-06-07 20:40:00 Trade opened: Sold at 195.69
# 2024-06-07 20:40:00 Holding the trade
# 2024-06-07 20:45:00 Closing the trade with market order
# 2024-06-07 20:45:00 Placing BUY market order for 200 units
# 2024-06-07 20:45:00 Placed BUY market order for 200 units at price 195.81
# 2024-06-07 20:45:00 Trade closed: Bought back at 195.81
# 2024-06-07 20:45:00 Gross profit from trade: -0.061284 %
# 2024-06-07 20:45:00 ........ wait for 60 secs .........
# 2024-06-07 20:46:00 Data downloaded
# 2024-06-07 20:46:00 Condition met (0.014509), open trade with market order
# 2024-06-07 20:46:00 Placing SELL market order for 200 units
# 2024-06-07 20:46:01 Placed SELL market order for 200 units at price 195.77
# 2024-06-07 20:46:01 Trade opened: Sold at 195.77
# 2024-06-07 20:46:01 Holding the trade
# 2024-06-07 20:51:01 Closing the trade with market order
# 2024-06-07 20:51:01 Placing BUY market order for 200 units
# 2024-06-07 20:51:02 Placed BUY market order for 200 units at price 195.75
# 2024-06-07 20:51:02 Trade closed: Bought back at 195.75
# 2024-06-07 20:51:02 Gross profit from trade: 0.010217 %
# 2024-06-07 20:51:02 ........ wait for 60 secs .........
# 2024-06-07 20:52:02 Data downloaded
# 2024-06-07 20:52:02 Condition met (0.014146), open trade with market order
# 2024-06-07 20:52:02 Placing SELL market order for 200 units
# 2024-06-07 20:52:02 Placed SELL market order for 200 units at price 195.71
# 2024-06-07 20:52:02 Trade opened: Sold at 195.71
# 2024-06-07 20:52:02 Holding the trade
# 2024-06-07 20:57:02 Closing the trade with market order
# 2024-06-07 20:57:02 Placing BUY market order for 200 units
# 2024-06-07 20:57:03 Placed BUY market order for 200 units at price 195.81
# 2024-06-07 20:57:03 Trade closed: Bought back at 195.81
# 2024-06-07 20:57:03 Gross profit from trade: -0.05107 %
# 2024-06-07 20:57:03 ........ wait for 60 secs .........
# 2024-06-07 20:58:03 Data downloaded
# 2024-06-07 20:58:03 Condition met (0.014768), open trade with market order
# 2024-06-07 20:58:03 Placing SELL market order for 200 units
# 2024-06-07 20:58:04 Placed SELL market order for 200 units at price 195.84
# 2024-06-07 20:58:04 Trade opened: Sold at 195.84
# 2024-06-07 20:58:04 Holding the trade
# 2024-06-07 21:03:04 Closing the trade with market order
# 2024-06-07 21:03:04 Placing BUY market order for 200 units
# 2024-06-07 21:03:04 Placed BUY market order for 200 units at price 195.95
# 2024-06-07 21:03:04 Trade closed: Bought back at 195.95
# 2024-06-07 21:03:04 Gross profit from trade: -0.056137 %
# 2024-06-07 21:03:04 ........ wait for 60 secs .........
